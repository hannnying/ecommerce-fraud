# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import chi2_contingency, mannwhitneyu

# %%
fraud_df = pd.read_csv("../data/Fraud_Data.csv")
ip_mapping = pd.read_csv("../data/IpAddress_to_Country.csv")

# %%
fraud_df.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
fraud_df.describe()
# Out:
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# min         2.000000        9.000000      18.000000  5.209350e+04
# 25%    100642.500000       22.000000      27.000000  1.085934e+09
# 50%    199958.000000       35.000000      33.000000  2.154770e+09
# 75%    300054.000000       49.000000      39.000000  3.243258e+09
# max    400000.000000      154.000000      76.000000  4.294850e+09
#
#                class
# count  151112.000000
# mean        0.093646
# std         0.291336
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
fraud_df.dtypes
# Out:
# user_id             int64
# signup_time        object
# purchase_time      object
# purchase_value      int64
# device_id          object
# source             object
# browser            object
# sex                object
# age                 int64
# ip_address        float64
# class               int64
# dtype: object

# %%
non_fraud = fraud_df["class"]==0
fraud = fraud_df["class"]==1

# %% [markdown]
# ## Distribution of Fraudulent and Non-Fraudulent Transactions

# %%
fraud_df["class"].value_counts(normalize=True)
# Out:
# class
# 0    0.906354
# 1    0.093646
# Name: proportion, dtype: float64

# %% [markdown]
# ## Number of Transactions by User, Device and IP Address
# This section shows how many transactions were made by each `user_id`, `device_id`, and `ip_address`.

# %%
def num_transactions_by_id(df, cols=["user_id", "device_id", "ip_address"]):
    for col in cols:
        df[f"transactions_by_{col}"] = df.groupby(col)[col].transform('count')
    return df

# %%
df = num_transactions_by_id(fraud_df)

# %%
df["transactions_by_user_id"].value_counts()
# Out:
# transactions_by_user_id
# 1    151112
# Name: count, dtype: int64

# %%
def plot_transaction_distributions(df, cols=["transactions_by_device_id", "transactions_by_ip_address"]):
    """
    Plot KDE distributions for given transaction columns.
    For each column, plot linear and log-scaled KDEs.
    """
    fig, axes = plt.subplots(len(cols), 2, figsize=(14, 5 * len(cols)))

    if len(cols) == 1:
        axes = [axes]  # make it iterable if only one row

    for i, col in enumerate(cols):
        # Linear scale KDE
        sns.kdeplot(data=df, x=col, fill=True, ax=axes[i][0])
        axes[i][0].set_title(f"{col} (Linear Scale)")
        axes[i][0].set_xlabel("Transaction Count")

        # Log scale KDE
        sns.kdeplot(data=df, x=np.log(df[col]), fill=True, ax=axes[i][1])
        axes[i][1].set_title(f"{col} (Log Scale)")
        axes[i][1].set_xlabel("Log(Transaction Count)")

    plt.tight_layout()
    plt.show()

plot_transaction_distributions(df)

# %% [markdown]
# Despite applying log transformation to `transactions_by_device_id` and `transactions_by_ip_address`, there are still outliers. Investigate if the outliers are due to the transaction being fraudulent or not.

# %%
def plot_boxplot_by_class(df, columns=['transactions_by_device_id', 'transactions_by_ip_address'], class_column='class'):
    # Loop through each column (transactions) to create boxplots
    for column in columns:
        plt.figure(figsize=(10, 6))
        sns.boxplot(x=class_column, y=column, data=df)
        plt.title(f"Boxplot of {column} by {class_column}")
        plt.xlabel(f"{class_column}")
        plt.ylabel(f"{column}")
        plt.xticks(rotation=90)  # Rotate x-axis labels if needed
        plt.show()

        # Identifying outliers by class (using IQR method)
        outlier_counts = df.groupby(class_column).apply(
            lambda x: ((x[column] < x[column].quantile(0.25) - 1.5 * (x[column].quantile(0.75) - x[column].quantile(0.25))) | 
                       (x[column] > x[column].quantile(0.75) + 1.5 * (x[column].quantile(0.75) - x[column].quantile(0.25)))).sum()
        )

        # Print out the number of outliers for each class
        print(f"Outliers by class for {column}:")
        print(outlier_counts)
        print("\n")

# Example usage
plot_boxplot_by_class(df)
# Out:
# Outliers by class for transactions_by_device_id:
# class
# 0    9190
# 1       0
# dtype: int64
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/3698928097.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   outlier_counts = df.groupby(class_column).apply(
# Outliers by class for transactions_by_ip_address:
# class
# 0    726
# 1      0
# dtype: int64
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/3698928097.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   outlier_counts = df.groupby(class_column).apply(

# %%
df.groupby("class")["transactions_by_device_id"].value_counts(normalize=True)
# Out:
# class  transactions_by_device_id
# 0      1                            0.932901
#        2                            0.059973
#        3                            0.001489
#        11                           0.000745
#        10                           0.000679
#        12                           0.000643
#        9                            0.000570
#        8                            0.000504
#        13                           0.000475
#        14                           0.000423
#        7                            0.000358
#        15                           0.000343
#        16                           0.000277
#        6                            0.000219
#        17                           0.000102
#        5                            0.000095
#        18                           0.000080
#        4                            0.000044
#        20                           0.000044
#        19                           0.000037
# 1      1                            0.283372
#        2                            0.172426
#        11                           0.071302
#        12                           0.070101
#        10                           0.058441
#        13                           0.054201
#        14                           0.052293
#        9                            0.044096
#        15                           0.040139
#        16                           0.038019
#        8                            0.034132
#        7                            0.021271
#        17                           0.014628
#        18                           0.011943
#        6                            0.010176
#        20                           0.008056
#        19                           0.006360
#        3                            0.004664
#        5                            0.003675
#        4                            0.000707
# Name: proportion, dtype: float64

# %%
df.groupby("class")["transactions_by_ip_address"].value_counts(normalize=True)
# Out:
# class  transactions_by_ip_address
# 0      1                             0.994699
#        11                            0.000686
#        10                            0.000635
#        12                            0.000635
#        9                             0.000555
#        8                             0.000504
#        13                            0.000438
#        14                            0.000409
#        7                             0.000343
#        15                            0.000263
#        16                            0.000256
#        6                             0.000212
#        5                             0.000095
#        17                            0.000088
#        18                            0.000066
#        19                            0.000044
#        20                            0.000029
#        4                             0.000022
#        3                             0.000015
#        2                             0.000007
# 1      1                             0.460533
#        11                            0.071090
#        12                            0.071020
#        10                            0.056745
#        13                            0.054554
#        14                            0.054413
#        9                             0.046781
#        16                            0.038231
#        15                            0.035616
#        8                             0.035263
#        7                             0.021412
#        17                            0.013568
#        18                            0.010812
#        6                             0.010671
#        19                            0.008975
#        20                            0.005371
#        5                             0.003675
#        4                             0.000919
#        3                             0.000283
#        2                             0.000071
# Name: proportion, dtype: float64

# %% [markdown]
# Non-fraudulent transactions (Class 0) exhibit a more distributed and irregular pattern, with a significant number of devices and IP addresses making just one transaction. Specifically, 127,771 devices and 136,235 IP addresses in Class 0 are associated with only a single transaction, indicating that the majority of legitimate users interact with the system via a single device or IP address, typically only once. This creates a clear, concentrated peak at one transaction per device or IP.
#
# In contrast, fraudulent transactions (Class 1) show a more concentrated but less extreme pattern. While the distribution is still more regular compared to Class 0, it lacks the large number of extreme outliers seen in the non-fraudulent group. Instead, many of the fraudulent transactions are spread across a smaller number of devices/IPs, with a moderate number of transactions per device or IP address. This suggests that, while fewer devices and IPs are involved overall, they tend to generate a moderate number of transactions. This pattern may indicate that fraudsters often use the same device or IP for multiple transactions, but not in extreme, single-device/IP clusters as seen in non-fraudulent transactions.
#
# In summary, the lack of extreme outliers in Class 1 (fraudulent) reflects a situation where a relatively small number of devices and IP addresses make several transactions, rather than the pattern in Class 0, where the majority of devices/IPs make just one transaction. This highlights the repeated, albeit less extreme nature of fraudulent activities compared to the largely one-time usage pattern seen with legitimate users.

# %% [markdown]
# ### Create `country` by mapping `ip_address` in `fraud_df` to `country` in `ip_mapping`.

# %%
sorted(ip_mapping.values.tolist(), key=lambda x: x[0])
# Out:
# [[16777216.0, 16777471, 'Australia'],
#  [16777472.0, 16777727, 'China'],
#  [16777728.0, 16778239, 'China'],
#  [16778240.0, 16779263, 'Australia'],
#  [16779264.0, 16781311, 'China'],
#  [16781312.0, 16785407, 'Japan'],
#  [16785408.0, 16793599, 'China'],
#  [16793600.0, 16809983, 'Japan'],
#  [16809984.0, 16842751, 'Thailand'],
#  [16842752.0, 16843007, 'China'],
#  [16843008.0, 16843263, 'Australia'],
#  [16843264.0, 16843775, 'China'],
#  [16843776.0, 16844799, 'China'],
#  [16844800.0, 16846847, 'China'],
#  [16846848.0, 16850943, 'China'],
#  [16850944.0, 16859135, 'China'],
#  [16859136.0, 16875519, 'Japan'],
#  [16875520.0, 16908287, 'Thailand'],
#  [16908288.0, 16908799, 'China'],
#  [16908800.0, 16909055, 'China'],
#  [16909056.0, 16909311, 'Australia'],
#  [16909312.0, 16909567, 'China'],
#  [16909568.0, 16909823, 'China'],
#  [16909824.0, 16910335, 'China'],
#  [16910336.0, 16910591, 'China'],
#  [16910592.0, 16910847, 'China'],
#  [16910848.0, 16911359, 'China'],
#  [16911360.0, 16912383, 'China'],
#  [16912384.0, 16916479, 'China'],
#  [16916480.0, 16924671, 'China'],
#  [16924672.0, 16941055, 'China'],
#  [16941056.0, 16973823, 'Thailand'],
#  [16973824.0, 17039359, 'China'],
#  [17039360.0, 17039615, 'Australia'],
#  [17039616.0, 17039871, 'China'],
#  [17039872.0, 17040383, 'China'],
#  [17040384.0, 17040639, 'China'],
#  [17040640.0, 17040895, 'China'],
#  [17040896.0, 17041407, 'China'],
#  [17041408.0, 17043455, 'China'],
#  [17043456.0, 17047551, 'China'],
#  [17047552.0, 17055743, 'China'],
#  [17055744.0, 17072127, 'China'],
#  [17072128.0, 17104895, 'Thailand'],
#  [17104896.0, 17170431, 'Japan'],
#  [17170432.0, 17301503, 'India'],
#  [17301504.0, 17367039, 'China'],
#  [17367040.0, 17432575, 'Malaysia'],
#  [17432576.0, 17434623, 'China'],
#  [17434624.0, 17435135, 'China'],
#  [17435136.0, 17435391, 'Australia'],
#  [17435392.0, 17435647, 'China'],
#  [17435648.0, 17436671, 'China'],
#  [17436672.0, 17440767, 'China'],
#  [17440768.0, 17448959, 'China'],
#  [17448960.0, 17465343, 'China'],
#  [17465344.0, 17498111, 'Thailand'],
#  [17498112.0, 17563647, 'Korea Republic of'],
#  [17563648.0, 17825791, 'China'],
#  [17825792.0, 18087935, 'Korea Republic of'],
#  [18087936.0, 18153471, 'Thailand'],
#  [18153472.0, 18219007, 'Japan'],
#  [18219008.0, 18350079, 'India'],
#  [18350080.0, 18874367, 'China'],
#  [18874368.0, 18939903, 'Hong Kong'],
#  [18939904.0, 19005439, 'Japan'],
#  [19005440.0, 19136511, 'Taiwan; Republic of China (ROC)'],
#  [19136512.0, 19202047, 'Hong Kong'],
#  [19202048.0, 19267583, 'Philippines'],
#  [19267584.0, 19398655, 'India'],
#  [19398656.0, 19660799, 'Australia'],
#  [19660800.0, 19726335, 'Australia'],
#  [19726336.0, 19791871, 'China'],
#  [19791872.0, 19922943, 'Thailand'],
#  [19922944.0, 20054015, 'China'],
#  [20054016.0, 20119551, 'China'],
#  [20119552.0, 20185087, 'China'],
#  [20185088.0, 20447231, 'Viet Nam'],
#  [20447232.0, 20971519, 'China'],
#  [20971520.0, 21102591, 'Hong Kong'],
#  [21102592.0, 21233663, 'Japan'],
#  [21233664.0, 21495807, 'China'],
#  [21495808.0, 22020095, 'Japan'],
#  [22020096.0, 22544383, 'China'],
#  [22544384.0, 22806527, 'China'],
#  [22806528.0, 22937599, 'China'],
#  [22937600.0, 23068671, 'China'],
#  [23068672.0, 24117247, 'Korea Republic of'],
#  [24117248.0, 24379391, 'Japan'],
#  [24379392.0, 24641535, 'China'],
#  [24641536.0, 25165823, 'Australia'],
#  [25165824.0, 27262975, 'Australia'],
#  [27262976.0, 28311551, 'Taiwan; Republic of China (ROC)'],
#  [28311552.0, 28442623, 'Korea Republic of'],
#  [28442624.0, 28508159, 'Australia'],
#  [28508160.0, 28540927, 'Australia'],
#  [28540928.0, 28573695, 'Thailand'],
#  [28573696.0, 28835839, 'China'],
#  [28835840.0, 28966911, 'China'],
#  [28966912.0, 29032447, 'India'],
#  [29032448.0, 29097983, 'India'],
#  [29097984.0, 29360127, 'China'],
#  [29360128.0, 29884415, 'China'],
#  [29884416.0, 29949951, 'Taiwan; Republic of China (ROC)'],
#  [29949952.0, 30015487, 'Korea Republic of'],
#  [30015488.0, 30146559, 'China'],
#  [30146560.0, 30408703, 'China'],
#  [30408704.0, 31457279, 'Korea Republic of'],
#  [31457280.0, 33554431, 'Korea Republic of'],
#  [33554432.0, 34603007, 'France'],
#  [34603008.0, 35127295, 'European Union'],
#  [35127296.0, 35651583, 'United Kingdom'],
#  [35651584.0, 36700159, 'Italy'],
#  [36700160.0, 36962303, 'United Arab Emirates'],
#  [36962304.0, 37224447, 'Israel'],
#  [37224448.0, 37289983, 'Ukraine'],
#  [37289984.0, 37355519, 'Ukraine'],
#  [37355520.0, 37486591, 'Ukraine'],
#  [37486592.0, 37748735, 'Russian Federation'],
#  [37748736.0, 38273023, 'Sweden'],
#  [38273024.0, 38797311, 'Kazakhstan'],
#  [38797312.0, 39059455, 'Portugal'],
#  [39059456.0, 39321599, 'Greece'],
#  [39321600.0, 39583743, 'Saudi Arabia'],
#  [39583744.0, 39845887, 'Russian Federation'],
#  [39845888.0, 40370175, 'United Kingdom'],
#  [40370176.0, 40894463, 'Denmark'],
#  [40894464.0, 41418751, 'Italy'],
#  [41418752.0, 41943039, 'United Kingdom'],
#  [41943040.0, 42205183, 'Denmark'],
#  [42205184.0, 42467327, 'Kazakhstan'],
#  [42467328.0, 42991615, 'Spain'],
#  [42991616.0, 43253759, 'Iran (ISLAMIC Republic Of)'],
#  [43253760.0, 43515903, 'Norway'],
#  [43515904.0, 43778047, 'Spain'],
#  [43778048.0, 44040191, 'Italy'],
#  [44040192.0, 45088767, 'Germany'],
#  [45088768.0, 46137343, 'Iran (ISLAMIC Republic Of)'],
#  [46137344.0, 46661631, 'Italy'],
#  [46661632.0, 47185919, 'Germany'],
#  [47185920.0, 47710207, 'Germany'],
#  [47710208.0, 48234495, 'United Kingdom'],
#  [48234496.0, 49283071, 'Italy'],
#  [49283072.0, 49807359, 'Germany'],
#  [49807360.0, 50331647, 'Sweden'],
#  [50331648.0, 67108863, 'United States'],
#  [67108864.0, 83886079, 'United States'],
#  [83886080.0, 83951615, 'Syrian Arab Republic'],
#  [83951616.0, 83959807, 'Ukraine'],
#  [83959808.0, 83961855, 'Spain'],
#  [83961856.0, 83963903, 'Cyprus'],
#  [83963904.0, 83965951, 'Russian Federation'],
#  [83965952.0, 83967999, 'Czech Republic'],
#  [83968000.0, 83976191, 'Germany'],
#  [83976192.0, 83978239, 'Switzerland'],
#  [83978240.0, 83980287, 'Iraq'],
#  [83980288.0, 83982335, 'Switzerland'],
#  [83982336.0, 83984383, 'Germany'],
#  [83984384.0, 84017151, 'Germany'],
#  [84017152.0, 84021247, 'Italy'],
#  [84021248.0, 84023295, 'United Kingdom'],
#  [84023296.0, 84025343, 'Spain'],
#  [84025344.0, 84033535, 'Russian Federation'],
#  [84033536.0, 84037631, 'Netherlands'],
#  [84037632.0, 84039679, 'Turkey'],
#  [84039680.0, 84041727, 'Spain'],
#  [84041728.0, 84049919, 'United Kingdom'],
#  [84049920.0, 84082687, 'Romania'],
#  [84082688.0, 84148223, 'Russian Federation'],
#  [84148224.0, 84410367, 'Germany'],
#  [84410368.0, 84426751, 'Russian Federation'],
#  [84426752.0, 84434943, 'Russian Federation'],
#  [84434944.0, 84443135, 'Italy'],
#  [84443136.0, 84451327, 'Lebanon'],
#  [84451328.0, 84455423, 'Russian Federation'],
#  [84455424.0, 84457471, 'Russian Federation'],
#  [84457472.0, 84459519, 'Spain'],
#  [84459520.0, 84467711, 'Russian Federation'],
#  [84467712.0, 84471807, 'Russian Federation'],
#  [84471808.0, 84473855, 'Iraq'],
#  [84473856.0, 84475903, 'Hungary'],
#  [84475904.0, 84541439, 'Germany'],
#  [84541440.0, 84543487, 'Germany'],
#  [84543488.0, 84545535, 'Germany'],
#  [84545536.0, 84549631, 'United Kingdom'],
#  [84549632.0, 84551679, 'Georgia'],
#  [84551680.0, 84553727, 'Germany'],
#  [84553728.0, 84557823, 'Germany'],
#  [84557824.0, 84574207, 'Netherlands'],
#  [84574208.0, 84576255, 'France'],
#  [84576256.0, 84578303, 'United Kingdom'],
#  [84578304.0, 84582399, 'United Kingdom'],
#  [84582400.0, 84590591, 'Germany'],
#  [84590592.0, 84592639, 'Netherlands'],
#  [84592640.0, 84594687, 'Spain'],
#  [84594688.0, 84598783, 'Germany'],
#  [84598784.0, 84600831, 'Iraq'],
#  [84600832.0, 84602879, 'United Kingdom'],
#  [84602880.0, 84606975, 'Azerbaijan'],
#  [84606976.0, 84609023, 'Austria'],
#  [84609024.0, 84611071, 'United Kingdom'],
#  [84611072.0, 84615167, 'United Kingdom'],
#  [84615168.0, 84617215, 'Italy'],
#  [84617216.0, 84619263, 'Palestinian Territory Occupied'],
#  [84619264.0, 84621311, 'Germany'],
#  [84621312.0, 84623359, 'Greece'],
#  [84623360.0, 84627455, 'Russian Federation'],
#  [84627456.0, 84629503, 'United Kingdom'],
#  [84629504.0, 84631551, 'United Kingdom'],
#  [84631552.0, 84639743, 'Italy'],
#  [84639744.0, 84672511, 'Turkey'],
#  [84672512.0, 84934655, 'Romania'],
#  [84934656.0, 85196799, 'Russian Federation'],
#  [85196800.0, 85262335, 'Lithuania'],
#  [85262336.0, 85327871, 'Oman'],
#  [85327872.0, 85360639, 'Iran (ISLAMIC Republic Of)'],
#  [85360640.0, 85362687, 'Israel'],
#  [85362688.0, 85364735, 'United Kingdom'],
#  [85364736.0, 85366783, 'Germany'],
#  [85366784.0, 85368831, 'Czech Republic'],
#  [85368832.0, 85377023, 'Serbia'],
#  [85377024.0, 85385215, 'Iran (ISLAMIC Republic Of)'],
#  [85385216.0, 85387263, 'United Kingdom'],
#  [85387264.0, 85389311, 'Sweden'],
#  [85389312.0, 85391359, 'Germany'],
#  [85391360.0, 85393407, 'Netherlands'],
#  [85393408.0, 85401599, 'European Union'],
#  [85401600.0, 85403647, 'Italy'],
#  [85403648.0, 85405695, 'France'],
#  [85405696.0, 85407743, 'Russian Federation'],
#  [85407744.0, 85409791, 'Finland'],
#  [85409792.0, 85417983, 'Switzerland'],
#  [85417984.0, 85420031, 'Russian Federation'],
#  [85420032.0, 85422079, 'Russian Federation'],
#  [85422080.0, 85424127, 'Iran (ISLAMIC Republic Of)'],
#  [85424128.0, 85426175, 'Turkey'],
#  [85426176.0, 85458943, 'Belgium'],
#  [85458944.0, 85721087, 'Turkey'],
#  [85721088.0, 85723135, 'Hungary'],
#  [85723136.0, 85725183, 'Italy'],
#  [85725184.0, 85729279, 'Russian Federation'],
#  [85729280.0, 85731327, 'Iran (ISLAMIC Republic Of)'],
#  [85731328.0, 85733375, 'Germany'],
#  [85733376.0, 85735423, 'United Kingdom'],
#  [85735424.0, 85737471, 'United Kingdom'],
#  [85737472.0, 85753855, 'Germany'],
#  [85753856.0, 85770239, 'Israel'],
#  [85770240.0, 85786623, 'Germany'],
#  [85786624.0, 85852159, 'Israel'],
#  [85852160.0, 85983231, 'United Arab Emirates'],
#  [85983232.0, 86015999, 'United Arab Emirates'],
#  [86016000.0, 86018047, 'Bulgaria'],
#  [86018048.0, 86020095, 'Slovenia'],
#  [86020096.0, 86022143, 'Russian Federation'],
#  [86022144.0, 86024191, 'United Kingdom'],
#  [86024192.0, 86026239, 'Germany'],
#  [86026240.0, 86028287, 'Moldova Republic of'],
#  [86028288.0, 86030335, 'Macedonia'],
#  [86030336.0, 86032383, 'Germany'],
#  [86032384.0, 86048767, 'Oman'],
#  [86048768.0, 86114303, 'Denmark'],
#  [86114304.0, 86147071, 'Kazakhstan'],
#  [86147072.0, 86155263, 'Spain'],
#  [86155264.0, 86157311, 'Palestinian Territory Occupied'],
#  [86157312.0, 86159359, 'Israel'],
#  [86159360.0, 86161407, 'Ukraine'],
#  [86161408.0, 86163455, 'Italy'],
#  [86163456.0, 86171647, 'Iran (ISLAMIC Republic Of)'],
#  [86171648.0, 86173695, 'Germany'],
#  [86173696.0, 86175743, 'Netherlands'],
#  [86175744.0, 86177791, 'Estonia'],
#  [86177792.0, 86179839, 'Liechtenstein'],
#  [86179840.0, 86212607, 'Russian Federation'],
#  [86212608.0, 86220799, 'Russian Federation'],
#  [86220800.0, 86222847, 'Russian Federation'],
#  [86222848.0, 86224895, 'Russian Federation'],
#  [86224896.0, 86226943, 'Netherlands'],
#  [86226944.0, 86228991, 'Sweden'],
#  [86228992.0, 86231039, 'Belgium'],
#  [86231040.0, 86233087, 'Spain'],
#  [86233088.0, 86235135, 'Romania'],
#  [86235136.0, 86237183, 'Spain'],
#  [86237184.0, 86245375, 'Germany'],
#  [86245376.0, 86376447, 'Oman'],
#  [86376448.0, 86409215, 'United Arab Emirates'],
#  [86409216.0, 86441983, 'Hungary'],
#  [86441984.0, 86474751, 'France'],
#  [86474752.0, 86482943, 'Croatia (LOCAL Name: Hrvatska)'],
#  [86482944.0, 86484991, 'Russian Federation'],
#  [86484992.0, 86487039, 'Netherlands'],
#  [86487040.0, 86489087, 'United Kingdom'],
#  [86489088.0, 86491135, 'Netherlands'],
#  [86491136.0, 86493183, 'Poland'],
#  [86493184.0, 86495231, 'Russian Federation'],
#  [86495232.0, 86497279, 'Spain'],
#  [86497280.0, 86499327, 'Netherlands'],
#  [86499328.0, 86501375, 'France'],
#  [86501376.0, 86503423, 'France'],
#  [86503424.0, 86505471, 'Germany'],
#  [86505472.0, 86507519, 'United Kingdom'],
#  [86507520.0, 86573055, 'Spain'],
#  [86573056.0, 86638591, 'Romania'],
#  [86638592.0, 86671359, 'Russian Federation'],
#  [86671360.0, 86673407, 'United Kingdom'],
#  [86673408.0, 86675455, 'Germany'],
#  [86675456.0, 86677503, 'Italy'],
#  [86677504.0, 86679551, 'France'],
#  [86679552.0, 86687743, 'Romania'],
#  [86687744.0, 86695935, 'Iraq'],
#  [86695936.0, 86704127, 'Saudi Arabia'],
#  [86704128.0, 86720511, 'Portugal'],
#  [86720512.0, 86736895, 'Bosnia and Herzegowina'],
#  [86736896.0, 86745087, 'Russian Federation'],
#  [86745088.0, 86753279, 'Croatia (LOCAL Name: Hrvatska)'],
#  [86753280.0, 86761471, 'Palestinian Territory Occupied'],
#  [86761472.0, 86763519, 'Czech Republic'],
#  [86763520.0, 86765567, 'Italy'],
#  [86765568.0, 86767615, 'Russian Federation'],
#  [86767616.0, 86769663, 'Italy'],
#  [86769664.0, 86773759, 'Russian Federation'],
#  [86773760.0, 86777855, 'United Kingdom'],
#  [86777856.0, 86779903, 'Azerbaijan'],
#  [86779904.0, 86781951, 'Russian Federation'],
#  [86781952.0, 86786047, 'Russian Federation'],
#  [86786048.0, 86788095, 'Norway'],
#  [86788096.0, 86790143, 'Netherlands'],
#  [86790144.0, 86794239, 'Turkey'],
#  [86794240.0, 86798335, 'Germany'],
#  [86798336.0, 86802431, 'Switzerland'],
#  [86802432.0, 86804479, 'Georgia'],
#  [86804480.0, 86806527, 'Denmark'],
#  [86806528.0, 86810623, 'Turkey'],
#  [86810624.0, 86812671, 'France'],
#  [86812672.0, 86814719, 'Russian Federation'],
#  [86814720.0, 86816767, 'Sweden'],
#  [86816768.0, 86818815, 'Estonia'],
#  [86818816.0, 86822911, 'Portugal'],
#  [86822912.0, 86824959, 'Austria'],
#  [86824960.0, 86827007, 'Latvia'],
#  [86827008.0, 86829055, 'United Kingdom'],
#  [86829056.0, 86831103, 'United Kingdom'],
#  [86831104.0, 86833151, 'Finland'],
#  [86833152.0, 86835199, 'United Kingdom'],
#  [86835200.0, 86837247, 'Germany'],
#  [86837248.0, 86839295, 'Spain'],
#  [86839296.0, 86843391, 'United Kingdom'],
#  [86847488.0, 86849535, 'United Kingdom'],
#  [86849536.0, 86851583, 'Czech Republic'],
#  [86851584.0, 86859775, 'Russian Federation'],
#  [86859776.0, 86863871, 'Germany'],
#  [86863872.0, 86865919, 'Estonia'],
#  [86865920.0, 86867967, 'Estonia'],
#  [86867968.0, 86872063, 'Jordan'],
#  [86872064.0, 86874111, 'United Kingdom'],
#  [86874112.0, 86876159, 'Norway'],
#  [86876160.0, 86880255, 'Spain'],
#  [86880256.0, 86882303, 'Germany'],
#  [86882304.0, 86884351, 'Lebanon'],
#  [86884352.0, 86900735, 'Russian Federation'],
#  [86900736.0, 87031807, 'Turkey'],
#  [87031808.0, 87293951, 'France'],
#  [87293952.0, 87359487, 'Iran (ISLAMIC Republic Of)'],
#  [87359488.0, 87361535, 'Spain'],
#  [87361536.0, 87363583, 'Czech Republic'],
#  [87363584.0, 87367679, 'Russian Federation'],
#  [87367680.0, 87375871, 'Iran (ISLAMIC Republic Of)'],
#  [87375872.0, 87384063, 'United Kingdom'],
#  [87384064.0, 87386111, 'United Arab Emirates'],
#  [87386112.0, 87388159, 'Switzerland'],
#  [87388160.0, 87390207, 'Ukraine'],
#  [87390208.0, 87392255, 'Russian Federation'],
#  [87392256.0, 87425023, 'Bulgaria'],
#  [87425024.0, 87556095, 'Greece'],
#  [87556096.0, 87558143, 'Spain'],
#  [87558144.0, 87560191, 'Italy'],
#  [87560192.0, 87562239, 'Germany'],
#  [87562240.0, 87564287, 'Ukraine'],
#  [87564288.0, 87566335, 'Hungary'],
#  [87566336.0, 87568383, 'France'],
#  [87568384.0, 87570431, 'United Kingdom'],
#  [87570432.0, 87572479, 'Spain'],
#  [87572480.0, 87588863, 'Moldova Republic of'],
#  [87588864.0, 87590911, 'United Kingdom'],
#  [87590912.0, 87592959, 'Russian Federation'],
#  [87592960.0, 87597055, 'Denmark'],
#  [87597056.0, 87599103, 'Spain'],
#  [87599104.0, 87601151, 'United Kingdom'],
#  [87601152.0, 87605247, 'Germany'],
#  [87605248.0, 87621631, 'Germany'],
#  [87621632.0, 87623679, 'Lebanon'],
#  [87623680.0, 87625727, 'Kyrgyzstan'],
#  [87625728.0, 87627775, 'Netherlands'],
#  [87627776.0, 87629823, 'Spain'],
#  [87629824.0, 87631871, 'Iran (ISLAMIC Republic Of)'],
#  [87631872.0, 87633919, 'Germany'],
#  [87633920.0, 87635967, 'Denmark'],
#  [87635968.0, 87638015, 'United Kingdom'],
#  [87638016.0, 87640063, 'Ukraine'],
#  [87640064.0, 87642111, 'Serbia'],
#  [87642112.0, 87646207, 'United Kingdom'],
#  [87646208.0, 87654399, 'France'],
#  [87654400.0, 87670783, 'Poland'],
#  [87670784.0, 87672831, 'Germany'],
#  [87672832.0, 87674879, 'Switzerland'],
#  [87674880.0, 87676927, 'United Arab Emirates'],
#  [87676928.0, 87678975, 'Russian Federation'],
#  [87678976.0, 87681023, 'Netherlands'],
#  [87681024.0, 87683071, 'Russian Federation'],
#  [87683072.0, 87685119, 'Sweden'],
#  [87685120.0, 87687167, 'Netherlands'],
#  [87687168.0, 87752703, 'Ukraine'],
#  [87752704.0, 87818239, 'Czech Republic'],
#  [87818240.0, 87883775, 'Poland'],
#  [87883776.0, 87885823, 'Italy'],
#  [87885824.0, 87887871, 'Russian Federation'],
#  [87887872.0, 87889919, 'Russian Federation'],
#  [87889920.0, 87891967, 'Iran (ISLAMIC Republic Of)'],
#  [87891968.0, 87900159, 'United Kingdom'],
#  [87900160.0, 87902207, 'Germany'],
#  [87902208.0, 87904255, 'Iran (ISLAMIC Republic Of)'],
#  [87904256.0, 87906303, 'Germany'],
#  [87906304.0, 87908351, 'Finland'],
#  [87908352.0, 87912447, 'Bulgaria'],
#  [87912448.0, 87914495, 'Ireland'],
#  [87914496.0, 87916543, 'United Kingdom'],
#  [87916544.0, 87932927, 'Germany'],
#  [87932928.0, 87934975, 'United Kingdom'],
#  [87934976.0, 87937023, 'Spain'],
#  [87937024.0, 87939071, 'Spain'],
#  [87939072.0, 87941119, 'Italy'],
#  [87941120.0, 87943167, 'Switzerland'],
#  [87943168.0, 87945215, 'Russian Federation'],
#  [87945216.0, 87947263, 'Hungary'],
#  [87947264.0, 87949311, 'Netherlands'],
#  [87949312.0, 87965695, 'United Kingdom'],
#  [87965696.0, 87967743, 'Germany'],
#  [87967744.0, 87969791, 'Germany'],
#  [87969792.0, 87973887, 'Germany'],
#  [87973888.0, 87982079, 'Germany'],
#  [87982080.0, 88014847, 'Russian Federation'],
#  [88014848.0, 88016895, 'Libyan Arab Jamahiriya'],
#  [88016896.0, 88018943, 'Iran (ISLAMIC Republic Of)'],
#  [88018944.0, 88020991, 'United Kingdom'],
#  [88020992.0, 88023039, 'France'],
#  [88023040.0, 88031231, 'Turkey'],
#  [88031232.0, 88047615, 'Kazakhstan'],
#  [88047616.0, 88049663, 'Russian Federation'],
#  [88049664.0, 88051711, 'Italy'],
#  [88051712.0, 88053759, 'United Kingdom'],
#  [88053760.0, 88055807, 'Russian Federation'],
#  [88055808.0, 88057855, 'Armenia'],
#  [88057856.0, 88059903, 'Italy'],
#  [88059904.0, 88061951, 'Germany'],
#  [88061952.0, 88063999, 'Poland'],
#  [88064000.0, 88080383, 'Hungary'],
#  [88080384.0, 88604671, 'United Kingdom'],
#  [88604672.0, 88866815, 'Russian Federation'],
#  [88866816.0, 88932351, 'Kazakhstan'],
#  [88932352.0, 88940543, 'Russian Federation'],
#  [88940544.0, 88948735, 'United Kingdom'],
#  [88948736.0, 88965119, 'Italy'],
#  [88965120.0, 88997887, 'Armenia'],
#  [88997888.0, 89063423, 'Germany'],
#  [89063424.0, 89079807, 'United Kingdom'],
#  [89079808.0, 89096191, 'Netherlands'],
#  [89096192.0, 89128959, 'Russian Federation'],
#  [89128960.0, 89260031, 'United Kingdom'],
#  [89260032.0, 89325567, 'Saudi Arabia'],
#  [89325568.0, 89327615, 'Netherlands'],
#  [89327616.0, 89329663, 'United Kingdom'],
#  [89329664.0, 89331711, 'Ukraine'],
#  [89331712.0, 89333759, 'Denmark'],
#  [89333760.0, 89337855, 'Romania'],
#  [89337856.0, 89339903, 'Spain'],
#  [89339904.0, 89341951, 'Finland'],
#  [89341952.0, 89350143, 'Spain'],
#  [89350144.0, 89352191, 'United Kingdom'],
#  [89352192.0, 89354239, 'Italy'],
#  [89354240.0, 89356287, 'United Arab Emirates'],
#  [89356288.0, 89358335, 'Italy'],
#  [89358336.0, 89374719, 'Germany'],
#  [89374720.0, 89382911, 'United Kingdom'],
#  [89382912.0, 89384959, 'Norway'],
#  [89384960.0, 89387007, 'France'],
#  [89387008.0, 89391103, 'Ireland'],
#  [89391104.0, 89653247, 'Italy'],
#  [89653248.0, 90177535, 'Italy'],
#  [90177536.0, 90439679, 'Italy'],
#  [90439680.0, 90456063, 'Germany'],
#  [90456064.0, 90472447, 'Russian Federation'],
#  [90472448.0, 90476543, 'Germany'],
#  [90476544.0, 90478591, 'France'],
#  [90478592.0, 90480639, 'United Kingdom'],
#  [90480640.0, 90482687, 'Yemen'],
#  [90482688.0, 90484735, 'United Kingdom'],
#  [90484736.0, 90488831, 'Norway'],
#  [90488832.0, 90497023, 'Belarus'],
#  [90497024.0, 90499071, 'Netherlands'],
#  [90499072.0, 90501119, 'Italy'],
#  [90501120.0, 90503167, 'United Kingdom'],
#  [90503168.0, 90505215, 'Israel'],
#  [90505216.0, 90521599, 'Russian Federation'],
#  [90521600.0, 90529791, 'Russian Federation'],
#  [90529792.0, 90533887, 'Netherlands'],
#  [90533888.0, 90537983, 'Russian Federation'],
#  [90537984.0, 90540031, 'Russian Federation'],
#  [90540032.0, 90542079, 'Russian Federation'],
#  [90542080.0, 90544127, 'United Kingdom'],
#  [90544128.0, 90546175, 'Russian Federation'],
#  [90546176.0, 90548223, 'Germany'],
#  [90548224.0, 90550271, 'Russian Federation'],
#  [90550272.0, 90554367, 'Russian Federation'],
#  [90554368.0, 90562559, 'Russian Federation'],
#  [90562560.0, 90570751, 'Russian Federation'],
#  [90570752.0, 90578943, 'Italy'],
#  [90578944.0, 90583039, 'Iran (ISLAMIC Republic Of)'],
#  [90583040.0, 90587135, 'Czech Republic'],
#  [90587136.0, 90589183, 'Poland'],
#  [90589184.0, 90591231, 'France'],
#  [90591232.0, 90595327, 'United Kingdom'],
#  [90595328.0, 90603519, 'Palestinian Territory Occupied'],
#  [90603520.0, 90605567, 'Spain'],
#  [90605568.0, 90607615, 'Netherlands'],
#  [90607616.0, 90609663, 'Switzerland'],
#  [90609664.0, 90611711, 'Russian Federation'],
#  [90611712.0, 90613759, 'Germany'],
#  [90613760.0, 90615807, 'United Kingdom'],
#  [90615808.0, 90617855, 'Slovenia'],
#  [90617856.0, 90619903, 'United Kingdom'],
#  [90619904.0, 90636287, 'Israel'],
#  [90636288.0, 90701823, 'Denmark'],
#  [90701824.0, 90705919, 'Turkey'],
#  [90705920.0, 90707967, 'Czech Republic'],
#  [90707968.0, 90710015, 'Italy'],
#  [90710016.0, 90718207, 'Ukraine'],
#  [90718208.0, 90720255, 'European Union'],
#  [90720256.0, 90722303, 'Iraq'],
#  [90722304.0, 90724351, 'Finland'],
#  [90724352.0, 90726399, 'Switzerland'],
#  [90726400.0, 90728447, 'France'],
#  [90728448.0, 90730495, 'Germany'],
#  [90730496.0, 90734591, 'Netherlands'],
#  [90734592.0, 90736639, 'Syrian Arab Republic'],
#  [90736640.0, 90738687, 'Netherlands'],
#  [90738688.0, 90740735, 'Germany'],
#  [90740736.0, 90742783, 'Netherlands'],
#  [90742784.0, 90750975, 'Bulgaria'],
#  [90750976.0, 90753023, 'France'],
#  [90753024.0, 90755071, 'Russian Federation'],
#  [90755072.0, 90757119, 'Poland'],
#  [90757120.0, 90759167, 'Austria'],
#  [90759168.0, 90761215, 'Netherlands'],
#  [90761216.0, 90763263, 'Kazakhstan'],
#  [90763264.0, 90765311, 'Israel'],
#  [90765312.0, 90767359, 'Poland'],
#  [90767360.0, 90832895, 'Ukraine'],
#  [90832896.0, 90898431, 'Romania'],
#  [90898432.0, 90963967, 'Romania'],
#  [90963968.0, 91226111, 'Saudi Arabia'],
#  [91226112.0, 92274687, 'Iran (ISLAMIC Republic Of)'],
#  [92274688.0, 92536831, 'Russian Federation'],
#  [92536832.0, 92602367, 'Netherlands'],
#  [92602368.0, 92604415, 'Bosnia and Herzegowina'],
#  [92604416.0, 92606463, 'Poland'],
#  [92606464.0, 92608511, 'United Kingdom'],
#  [92608512.0, 92610559, 'Palestinian Territory Occupied'],
#  [92610560.0, 92612607, 'Switzerland'],
#  [92612608.0, 92614655, 'United Kingdom'],
#  [92614656.0, 92618751, 'Italy'],
#  [92635136.0, 92643327, 'Bosnia and Herzegowina'],
#  [92643328.0, 92645375, 'Georgia'],
#  [92645376.0, 92647423, 'United Kingdom'],
#  [92647424.0, 92649471, 'United Kingdom'],
#  [92649472.0, 92651519, 'United Kingdom'],
#  [92651520.0, 92659711, 'Sweden'],
#  [92659712.0, 92663807, 'Azerbaijan'],
#  [92663808.0, 92665855, 'United Kingdom'],
#  [92665856.0, 92667903, 'Poland'],
#  [92667904.0, 92669951, 'Belgium'],
#  [92669952.0, 92671999, 'United Kingdom'],
#  [92672000.0, 92674047, 'Germany'],
#  [92674048.0, 92676095, 'Switzerland'],
#  [92676096.0, 92680191, 'Spain'],
#  [92680192.0, 92684287, 'Azerbaijan'],
#  [92684288.0, 92688383, 'Poland'],
#  [92688384.0, 92690431, 'Armenia'],
#  [92690432.0, 92692479, 'Ireland'],
#  [92692480.0, 92694527, 'France'],
#  [92694528.0, 92696575, 'Serbia'],
#  [92696576.0, 92698623, 'Spain'],
#  [92698624.0, 92700671, 'Italy'],
#  [92700672.0, 92717055, 'Iran (ISLAMIC Republic Of)'],
#  [92717056.0, 92719103, 'Sweden'],
#  [92719104.0, 92721151, 'Syrian Arab Republic'],
#  [92721152.0, 92723199, 'Poland'],
#  [92723200.0, 92725247, 'Russian Federation'],
#  [92725248.0, 92733439, 'Syrian Arab Republic'],
#  [92733440.0, 92798975, 'France'],
#  [92798976.0, 93323263, 'Russian Federation'],
#  [93323264.0, 93331455, 'Switzerland'],
#  [93331456.0, 93333503, 'Switzerland'],
#  [93333504.0, 93335551, 'Switzerland'],
#  [93335552.0, 93339647, 'Israel'],
#  [93339648.0, 93343743, 'Russian Federation'],
#  [93343744.0, 93347839, 'United Kingdom'],
#  [93347840.0, 93356031, 'Russian Federation'],
#  [93356032.0, 93358079, 'Iran (ISLAMIC Republic Of)'],
#  [93358080.0, 93360127, 'France'],
#  [93360128.0, 93362175, 'Spain'],
#  [93362176.0, 93364223, 'United Kingdom'],
#  [93364224.0, 93368319, 'Italy'],
#  [93368320.0, 93370367, 'United Kingdom'],
#  [93370368.0, 93372415, 'Italy'],
#  [93372416.0, 93388799, 'Greece'],
#  [93388800.0, 93396991, 'Switzerland'],
#  [93396992.0, 93405183, 'Switzerland'],
#  [93405184.0, 93413375, 'Switzerland'],
#  [93413376.0, 93415423, 'Switzerland'],
#  [93415424.0, 93417471, 'Czech Republic'],
#  [93417472.0, 93419519, 'Iran (ISLAMIC Republic Of)'],
#  [93419520.0, 93421567, 'Italy'],
#  [93421568.0, 93425663, 'Germany'],
#  [93425664.0, 93427711, 'Gibraltar'],
#  [93427712.0, 93429759, 'Norway'],
#  [93429760.0, 93431807, 'Russian Federation'],
#  [93431808.0, 93433855, 'Spain'],
#  [93433856.0, 93435903, 'Germany'],
#  [93435904.0, 93437951, 'Germany'],
#  [93437952.0, 93454335, 'Russian Federation'],
#  [93454336.0, 93585407, 'Germany'],
#  [93585408.0, 93618175, 'United Kingdom'],
#  [93618176.0, 93626367, 'United Kingdom'],
#  [93626368.0, 93634559, 'Switzerland'],
#  [93634560.0, 93650943, 'Hungary'],
#  [93650944.0, 93652991, 'Switzerland'],
#  [93652992.0, 93655039, 'United Kingdom'],
#  [93655040.0, 93659135, 'Switzerland'],
#  [93659136.0, 93667327, 'Switzerland'],
#  [93667328.0, 93675519, 'Bosnia and Herzegowina'],
#  [93675520.0, 93679615, 'Iraq'],
#  [93679616.0, 93681663, 'Luxembourg'],
#  [93681664.0, 93683711, 'Ukraine'],
#  [93683712.0, 93685759, 'Austria'],
#  [93685760.0, 93687807, 'Belgium'],
#  [93687808.0, 93689855, 'Russian Federation'],
#  [93689856.0, 93691903, 'United Kingdom'],
#  [93691904.0, 93693951, 'Poland'],
#  [93693952.0, 93695999, 'Ireland'],
#  [93696000.0, 93700095, 'France'],
#  [93700096.0, 93702143, 'Poland'],
#  [93702144.0, 93704191, 'Russian Federation'],
#  [93704192.0, 93708287, 'Ukraine'],
#  [93708288.0, 93712383, 'Germany'],
#  [93712384.0, 93714431, 'Hungary'],
#  [93714432.0, 93716479, 'United Kingdom'],
#  [93716480.0, 93749247, 'United Kingdom'],
#  [93749248.0, 93753343, 'Italy'],
#  [93753344.0, 93755391, 'Ireland'],
#  [93755392.0, 93757439, 'United Kingdom'],
#  [93757440.0, 93765631, 'United Kingdom'],
#  [93765632.0, 93782015, 'Sweden'],
#  [93782016.0, 93847551, 'United Kingdom'],
#  [93847552.0, 93880319, 'Georgia'],
#  [93880320.0, 93888511, 'Italy'],
#  [93888512.0, 93890559, 'Poland'],
#  [93890560.0, 93892607, 'Spain'],
#  [93892608.0, 93894655, 'United Kingdom'],
#  [93894656.0, 93896703, 'United States'],
#  [93896704.0, 93904895, 'United Kingdom'],
#  [93904896.0, 93906943, 'Latvia'],
#  [93906944.0, 93908991, 'Bosnia and Herzegowina'],
#  [93908992.0, 93911039, 'Italy'],
#  [93911040.0, 93913087, 'United Arab Emirates'],
#  [93913088.0, 93929471, 'Netherlands'],
#  [93929472.0, 93937663, 'United Kingdom'],
#  [93937664.0, 93939711, 'United Kingdom'],
#  [93939712.0, 93941759, 'Norway'],
#  [93941760.0, 93945855, 'Switzerland'],
#  [93945856.0, 93962239, 'Ukraine'],
#  [93962240.0, 93970431, 'United Kingdom'],
#  [93970432.0, 93972479, 'United Kingdom'],
#  [93972480.0, 93974527, 'Estonia'],
#  [93974528.0, 93976575, 'Switzerland'],
#  [93976576.0, 93978623, 'United Kingdom'],
#  [93978624.0, 94109695, 'Romania'],
#  [94109696.0, 94175231, 'Romania'],
#  [94175232.0, 94191615, 'Estonia'],
#  [94191616.0, 94193663, 'United Kingdom'],
#  [94193664.0, 94195711, 'Slovenia'],
#  [94195712.0, 94197759, 'Netherlands'],
#  [94197760.0, 94199807, 'Netherlands'],
#  [94199808.0, 94207999, 'Italy'],
#  [94208000.0, 94240767, 'Romania'],
#  [94240768.0, 94257151, 'Portugal'],
#  [94257152.0, 94261247, 'Italy'],
#  [94261248.0, 94263295, 'Spain'],
#  [94263296.0, 94265343, 'United Kingdom'],
#  [94265344.0, 94273535, 'Russian Federation'],
#  [94273536.0, 94289919, 'Germany'],
#  [94289920.0, 94291967, 'Norway'],
#  [94291968.0, 94294015, 'France'],
#  [94294016.0, 94296063, 'United Kingdom'],
#  [94296064.0, 94298111, 'Spain'],
#  [94298112.0, 94300159, 'United Kingdom'],
#  [94300160.0, 94302207, 'Russian Federation'],
#  [94302208.0, 94306303, 'France'],
#  [94306304.0, 94308351, 'Austria'],
#  [94308352.0, 94310399, 'Spain'],
#  [94310400.0, 94312447, 'Georgia'],
#  [94312448.0, 94314495, 'Germany'],
#  [94314496.0, 94316543, 'Netherlands'],
#  [94316544.0, 94318591, 'Ireland'],
#  [94318592.0, 94320639, 'Iran (ISLAMIC Republic Of)'],
#  [94320640.0, 94322687, 'Germany'],
#  [94322688.0, 94330879, 'Germany'],
#  [94330880.0, 94334975, 'Russian Federation'],
#  [94334976.0, 94337023, 'Russian Federation'],
#  [94337024.0, 94339071, 'United Kingdom'],
#  [94339072.0, 94355455, 'Spain'],
#  [94355456.0, 94357503, 'Netherlands'],
#  [94357504.0, 94359551, 'United Kingdom'],
#  [94359552.0, 94361599, 'United Kingdom'],
#  [94361600.0, 94363647, 'Portugal'],
#  [94363648.0, 94365695, 'United Kingdom'],
#  [94365696.0, 94367743, 'Hungary'],
#  [94367744.0, 94369791, 'Spain'],
#  [94369792.0, 94371839, 'Turkey'],
#  [94371840.0, 94502911, 'Iran (ISLAMIC Republic Of)'],
#  [94502912.0, 94568447, 'Oman'],
#  [94568448.0, 94633983, 'Romania'],
#  [94633984.0, 94896127, 'Russian Federation'],
#  [94896128.0, 95158271, 'Italy'],
#  [95158272.0, 95166463, 'Russian Federation'],
#  [95166464.0, 95168511, 'Serbia'],
#  [95168512.0, 95170559, 'Netherlands'],
#  [95170560.0, 95174655, 'United Kingdom'],
#  [95174656.0, 95191039, 'Italy'],
#  [95191040.0, 95195135, 'Switzerland'],
#  [95195136.0, 95197183, 'Portugal'],
#  [95197184.0, 95199231, 'United Kingdom'],
#  [95199232.0, 95203327, 'United Kingdom'],
#  [95203328.0, 95205375, 'France'],
#  [95205376.0, 95207423, 'Poland'],
#  [95207424.0, 95211519, 'Greece'],
#  [95211520.0, 95213567, 'Italy'],
#  [95213568.0, 95215615, 'Netherlands'],
#  [95215616.0, 95223807, 'Poland'],
#  [95223808.0, 95289343, 'Poland'],
#  [95289344.0, 95354879, 'Poland'],
#  [95354880.0, 95363071, 'Germany'],
#  [95363072.0, 95365119, 'Italy'],
#  [95365120.0, 95367167, 'Spain'],
#  [95367168.0, 95369215, 'Italy'],
#  [95369216.0, 95371263, 'United Kingdom'],
#  [95371264.0, 95375359, 'Italy'],
#  [95375360.0, 95377407, 'Netherlands'],
#  [95377408.0, 95379455, 'Russian Federation'],
#  [95379456.0, 95387647, 'Russian Federation'],
#  [95387648.0, 95420415, 'Germany'],
#  [95420416.0, 95551487, 'Turkey'],
#  [95551488.0, 95555583, 'Azerbaijan'],
#  [95555584.0, 95557631, 'United Kingdom'],
#  [95557632.0, 95559679, 'Russian Federation'],
#  [95559680.0, 95561727, 'Netherlands'],
#  [95561728.0, 95563775, 'Italy'],
#  [95563776.0, 95567871, 'Slovakia (SLOVAK Republic)'],
#  [95567872.0, 95569919, 'Netherlands'],
#  [95569920.0, 95571967, 'Sweden'],
#  [95571968.0, 95574015, 'Russian Federation'],
#  [95574016.0, 95576063, 'Italy'],
#  [95576064.0, 95580159, 'United Kingdom'],
#  [95580160.0, 95582207, 'Netherlands'],
#  [95582208.0, 95584255, 'Italy'],
#  [95584256.0, 95617023, 'Georgia'],
#  [95617024.0, 95625215, 'Latvia'],
#  [95625216.0, 95633407, 'Ireland'],
#  [95633408.0, 95635455, 'Ireland'],
#  [95635456.0, 95637503, 'United Kingdom'],
#  [95637504.0, 95641599, 'Denmark'],
#  [95641600.0, 95645695, 'United Kingdom'],
#  [95645696.0, 95647743, 'Sweden'],
#  [95647744.0, 95649791, 'France'],
#  [95649792.0, 95666175, 'Italy'],
#  [95666176.0, 95668223, 'France'],
#  [95668224.0, 95670271, 'Germany'],
#  [95670272.0, 95672319, 'Germany'],
#  [95672320.0, 95674367, 'Germany'],
#  [95674368.0, 95676415, 'Germany'],
#  [95676416.0, 95678463, 'Germany'],
#  [95678464.0, 95680511, 'Germany'],
#  [95680512.0, 95682559, 'Germany'],
#  [95682560.0, 95944703, 'Ukraine'],
#  [95944704.0, 96075775, 'Poland'],
#  [96075776.0, 96141311, 'Germany'],
#  [96141312.0, 96143359, 'Spain'],
#  [96143360.0, 96145407, 'Georgia'],
#  [96145408.0, 96149503, 'United Kingdom'],
#  [96149504.0, 96151551, 'Spain'],
#  [96151552.0, 96153599, 'Russian Federation'],
#  [96153600.0, 96155647, 'Poland'],
#  [96155648.0, 96157695, 'Switzerland'],
#  [96157696.0, 96165887, 'Russian Federation'],
#  [96165888.0, 96174079, 'France'],
#  [96174080.0, 96206847, 'Hungary'],
#  [96206848.0, 96337919, 'Russian Federation'],
#  [96337920.0, 96403455, 'Iran (ISLAMIC Republic Of)'],
#  [96403456.0, 96468991, 'Azerbaijan'],
#  [96468992.0, 96731135, 'Romania'],
#  [96731136.0, 96796671, 'Germany'],
#  [96796672.0, 96862207, 'Azerbaijan'],
#  [96862208.0, 96894975, 'United Kingdom'],
#  [96894976.0, 96897023, 'Czech Republic'],
#  [96897024.0, 96899071, 'United Kingdom'],
#  [96899072.0, 96903167, 'Austria'],
#  [96903168.0, 96911359, 'Iran (ISLAMIC Republic Of)'],
#  [96911360.0, 96919551, 'France'],
#  [96919552.0, 96923647, 'Italy'],
#  [96923648.0, 96925695, 'Jordan'],
#  [96925696.0, 96927743, 'Malta'],
#  [96927744.0, 96960511, 'United Kingdom'],
#  [96960512.0, 96964607, 'Germany'],
#  [96964608.0, 96968703, 'Netherlands'],
#  [96968704.0, 96972799, 'Lithuania'],
#  [96972800.0, 96974847, 'Germany'],
#  [96974848.0, 96976895, 'Russian Federation'],
#  [96976896.0, 96985087, 'Russian Federation'],
#  [96985088.0, 96987135, 'Spain'],
#  [96987136.0, 96989183, 'Ukraine'],
#  [96989184.0, 96993279, 'Germany'],
#  [96993280.0, 97001471, 'Netherlands'],
#  [97001472.0, 97009663, 'Russian Federation'],
#  [97009664.0, 97017855, 'Iran (ISLAMIC Republic Of)'],
#  [97017856.0, 97026047, 'Iran (ISLAMIC Republic Of)'],
#  [97026048.0, 97058815, 'Iran (ISLAMIC Republic Of)'],
#  [97058816.0, 97091583, 'Poland'],
#  [97091584.0, 97124351, 'Iran (ISLAMIC Republic Of)'],
#  [97124352.0, 97189887, 'Iran (ISLAMIC Republic Of)'],
#  [97189888.0, 97255423, 'Greece'],
#  [97255424.0, 97320959, 'Hungary'],
#  [97320960.0, 97386495, 'Spain'],
#  [97386496.0, 97419263, 'Russian Federation'],
#  [97419264.0, 97435647, 'Hungary'],
#  [97435648.0, 97437695, 'Denmark'],
#  [97437696.0, 97439743, 'Austria'],
#  [97439744.0, 97443839, 'Netherlands'],
#  [97443840.0, 97445887, 'Portugal'],
#  [97445888.0, 97447935, 'Serbia'],
#  [97447936.0, 97452031, 'Poland'],
#  [97452032.0, 97517567, 'Ukraine'],
#  [97517568.0, 98566143, 'Iran (ISLAMIC Republic Of)'],
#  [98566144.0, 98697215, 'Netherlands'],
#  [98697216.0, 98699263, 'France'],
#  [98699264.0, 98701311, 'France'],
#  [98701312.0, 98705407, 'Spain'],
#  [98705408.0, 98707455, 'Sweden'],
#  [98707456.0, 98709503, 'Netherlands'],
#  [98709504.0, 98711551, 'Iran (ISLAMIC Republic Of)'],
#  [98711552.0, 98713599, 'United Kingdom'],
#  [98713600.0, 98729983, 'Poland'],
#  [98729984.0, 98732031, 'Poland'],
#  [98732032.0, 98734079, 'United Kingdom'],
#  [98734080.0, 98736127, 'Switzerland'],
#  [98736128.0, 98738175, 'Russian Federation'],
#  [98738176.0, 98740223, 'Norway'],
#  [98740224.0, 98742271, 'Spain'],
#  [98742272.0, 98744319, 'United Kingdom'],
#  [98744320.0, 98746367, 'Spain'],
#  [98746368.0, 98762751, 'Turkey'],
#  [98762752.0, 98828287, 'Russian Federation'],
#  [98828288.0, 98893823, 'Russian Federation'],
#  [98893824.0, 98959359, 'Turkey'],
#  [98959360.0, 99090431, 'Germany'],
#  [99090432.0, 99614719, 'Iran (ISLAMIC Republic Of)'],
#  [99614720.0, 99876863, 'Sweden'],
#  [99876864.0, 100139007, 'Saudi Arabia'],
#  [100139008.0, 100204543, 'Ukraine'],
#  [100204544.0, 100237311, 'Portugal'],
#  [100237312.0, 100245503, 'Italy'],
#  [100245504.0, 100247551, 'Sweden'],
#  [100247552.0, 100249599, 'Switzerland'],
#  [100249600.0, 100253695, 'Slovenia'],
#  [100253696.0, 100261887, 'Russian Federation'],
#  [100261888.0, 100270079, 'Norway'],
#  [100270080.0, 100302847, 'Iran (ISLAMIC Republic Of)'],
#  [100302848.0, 100311039, 'Kazakhstan'],
#  [100311040.0, 100313087, 'Finland'],
#  [100313088.0, 100315135, 'Russian Federation'],
#  [100315136.0, 100319231, 'United Kingdom'],
#  [100319232.0, 100327423, 'Azerbaijan'],
#  [100327424.0, 100329471, 'Sweden'],
#  [100329472.0, 100331519, 'Russian Federation'],
#  [100331520.0, 100335615, 'Turkey'],
#  [100335616.0, 100401151, 'Kazakhstan'],
#  [100532224.0, 100564991, 'Romania'],
#  [100564992.0, 100573183, 'Sweden'],
#  [100573184.0, 100575231, 'United Kingdom'],
#  [100575232.0, 100577279, 'Sweden'],
#  [100577280.0, 100579327, 'Russian Federation'],
#  [100579328.0, 100581375, 'Austria'],
#  [100581376.0, 100589567, 'Sweden'],
#  [100589568.0, 100597759, 'Russian Federation'],
#  [100597760.0, 100614143, 'Turkey'],
#  [100614144.0, 100622335, 'Netherlands'],
#  [100622336.0, 100630527, 'Netherlands'],
#  [100630528.0, 100632575, 'Belgium'],
#  [100632576.0, 100634623, 'United Kingdom'],
#  [100634624.0, 100636671, 'Spain'],
#  [100636672.0, 100638719, 'Netherlands'],
#  [100638720.0, 100642815, 'Ukraine'],
#  [100642816.0, 100646911, 'Ukraine'],
#  [100646912.0, 100663295, 'Russian Federation'],
#  [100663296.0, 117440511, 'United States'],
#  [117440512.0, 134217727, 'United States'],
#  [134217728.0, 150994943, 'United States'],
#  [150994944.0, 167772159, 'United States'],
#  [184549376.0, 201326591, 'United States'],
#  [201326592.0, 218103807, 'United States'],
#  [218103808.0, 222298111, 'United States'],
#  [222298112.0, 224395263, 'United States'],
#  [224395264.0, 224919551, 'United States'],
#  [224919552.0, 225181695, 'United States'],
#  [225181696.0, 225443839, 'United States'],
#  [225443840.0, 226492415, 'United States'],
#  [226492416.0, 234881023, 'United States'],
#  [234881024.0, 234883071, 'China'],
#  [234883072.0, 234884095, 'Japan'],
#  [234884096.0, 234885119, 'China'],
#  [234885120.0, 234889215, 'Viet Nam'],
#  [234889216.0, 234897407, 'Korea Republic of'],
#  [234897408.0, 234913791, 'Korea Republic of'],
#  [234913792.0, 234946559, 'Hong Kong'],
#  [234946560.0, 234947583, 'China'],
#  [234947584.0, 234948607, 'Japan'],
#  [234948608.0, 234950655, 'Japan'],
#  [234950656.0, 234951679, 'Australia'],
#  [234951680.0, 234952703, 'Hong Kong'],
#  [234954752.0, 234962943, 'New Zealand'],
#  [234962944.0, 234971135, 'New Zealand'],
#  [234979328.0, 235012095, 'Malaysia'],
#  [235012096.0, 235077631, 'Australia'],
#  [235077632.0, 235143167, 'Japan'],
#  [235143168.0, 235405311, 'Korea Republic of'],
#  [235405312.0, 235929599, 'Japan'],
#  [235929600.0, 236978175, 'China'],
#  [236978176.0, 239075327, 'Korea Republic of'],
#  [239075328.0, 241172479, 'Korea Republic of'],
#  [241172480.0, 241434623, 'India'],
#  [241434624.0, 241500159, 'Singapore'],
#  [241500160.0, 241565695, 'Japan'],
#  [241565696.0, 241598463, 'India'],
#  [241598464.0, 241599487, 'China'],
#  [241599488.0, 241600511, 'Japan'],
#  [241600512.0, 241602559, 'Australia'],
#  [241602560.0, 241604607, 'Malaysia'],
#  [241604608.0, 241605631, 'Indonesia'],
#  [241605632.0, 241606655, 'China'],
#  [241614848.0, 241623039, 'Japan'],
#  [241623040.0, 241627135, 'India'],
#  [241627136.0, 241631231, 'Hong Kong'],
#  [241631232.0, 241696767, 'China'],
#  [241696768.0, 242221055, 'China'],
#  [242221056.0, 243269631, 'China'],
#  [243269632.0, 243270655, 'Japan'],
#  [243270656.0, 243271679, 'New Zealand'],
#  [243271680.0, 243272703, 'Thailand'],
#  [243272704.0, 243273727, 'Nepal'],
#  [243273728.0, 243277823, 'Japan'],
#  [243277824.0, 243286015, 'Australia'],
#  [243286016.0, 243294207, 'Japan'],
#  [243294208.0, 243302399, 'Japan'],
#  [243302400.0, 243335167, 'Korea Republic of'],
#  [243335168.0, 243400703, 'Korea Republic of'],
#  [243400704.0, 243531775, 'China'],
#  [243531776.0, 243662847, 'Japan'],
#  [243662848.0, 243793919, 'China'],
#  [243793920.0, 243859455, 'Hong Kong'],
#  [243859456.0, 243892223, 'Australia'],
#  [243892224.0, 243908607, 'Australia'],
#  [243908608.0, 243916799, 'Australia'],
#  [243916800.0, 243924991, 'Japan'],
#  [243924992.0, 243990527, 'Korea Republic of'],
#  [243990528.0, 244056063, 'India'],
#  [244056064.0, 244318207, 'India'],
#  [244318208.0, 245366783, 'China'],
#  [245366784.0, 247463935, 'Viet Nam'],
#  [247472128.0, 247476223, 'Japan'],
#  [247476224.0, 247478271, 'Japan'],
#  [247478272.0, 247479295, 'Japan'],
#  [247479296.0, 247480319, 'China'],
#  [247480320.0, 247482367, 'Malaysia'],
#  [247482368.0, 247483391, 'Papua New Guinea'],
#  [247483392.0, 247484415, 'China'],
#  [247484416.0, 247488511, 'Korea Republic of'],
#  [247488512.0, 247496703, 'Japan'],
#  [247496704.0, 247504895, 'Pakistan'],
#  [247504896.0, 247513087, 'Australia'],
#  [247513088.0, 247529471, 'Malaysia'],
#  [247529472.0, 247595007, 'Japan'],
#  [247595008.0, 247726079, 'India'],
#  [247726080.0, 247857151, 'China'],
#  ...]

# %%
import logging

def map_ip_to_country(ip_address, ip_mapping):
    ip_mapping_list = ip_mapping.values.tolist()
    ip_mapping_list.sort(key=lambda x: x[0])

    l, r = 0, len(ip_mapping_list)-1

    while l <= r:
        m = (l + r) // 2
        if ip_mapping_list[m][0] <= ip_address <= ip_mapping_list[m][1]:
            return ip_mapping_list[m][2]
        
        elif ip_mapping_list[m][0] > ip_address:
            r = m - 1
        
        elif ip_address > ip_mapping_list[m][1]:
            l = m + 1
    
    logging.warning(f"IP address {ip_address} not found in any range.")
    return None   

def log_and_map_ip_to_country(ip_address, ip_mapping):
    country = map_ip_to_country(ip_address, ip_mapping)
    logging.info(f"IP Address {ip_address} mapped to country: {country}")
    return country

# %%
filepath = os.path.join(os.getcwd(), "../data/fraud_with_country.csv")
if os.path.exists(filepath):
        df = pd.read_csv(filepath)
else:
        df["country"] = df["ip_address"].apply(lambda x: log_and_map_ip_to_country(x, ip_mapping))

# %%
def generate_bargraph(df, value_column, class_column=None):
    """
    Generates a bar graph for the values in the specified column.
    
    Parameters:
        df (pandas.DataFrame): The dataframe containing the data.
        value_column (str): The column name for the values to plot.
        class_column (str, optional): The column name used for separating values by class.
    """
    # Check if the value_column exists in the DataFrame
    if value_column not in df.columns:
        raise ValueError(f"{value_column} does not exist in the DataFrame.")
    
    # If class_column is provided, separate the values by class
    if class_column and class_column in df.columns:
        grouped = df.groupby(class_column)[value_column].sum()
        grouped.plot(kind='bar', color='skyblue', figsize=(10, 6))
        plt.title(f'Bar Graph of {value_column} Grouped by {class_column}')
        plt.xlabel(class_column)
        plt.ylabel(value_column)
    else:
        # If no class_column is provided, just plot the values directly
        df[value_column].plot(kind='bar', color='skyblue', figsize=(10, 6))
        plt.title(f'Bar Graph of {value_column}')
        plt.xlabel('Index')
        plt.ylabel(value_column)

    # Show the plot
    plt.show()

# %% [markdown]
# ## Distribution of transactions from each country

# %%
df["country"].value_counts(normalize=True, dropna=False)
# Out:
# country
# United States     0.384146
# NaN               0.145362
# China             0.079663
# Japan             0.048348
# United Kingdom    0.029713
#                     ...
# Myanmar           0.000007
# Vanuatu           0.000007
# Dominica          0.000007
# Niger             0.000007
# Guadeloupe        0.000007
# Name: proportion, Length: 182, dtype: float64

# %%
df[non_fraud]["country"].value_counts(normalize=True, dropna=False)
# Out:
# country
# United States     0.383306
# NaN               0.146633
# China             0.080278
# Japan             0.048123
# United Kingdom    0.029300
#                     ...
# Myanmar           0.000007
# Vanuatu           0.000007
# Dominica          0.000007
# Niger             0.000007
# Guadeloupe        0.000007
# Name: proportion, Length: 181, dtype: float64

# %%
df[fraud]["country"].value_counts(normalize=True, dropna=False)
# Out:
# country
# United States     0.392269
# NaN               0.133065
# China             0.073705
# Japan             0.050526
# United Kingdom    0.033708
#                     ...
# Malawi            0.000071
# Serbia            0.000071
# Turkmenistan      0.000071
# Macedonia         0.000071
# Mauritius         0.000071
# Name: proportion, Length: 110, dtype: float64

# %%
# Count fraudulent transactions per country
country_stats = (
    df.groupby('country')
    .agg(
        transactions=('class', 'count'),
        frauds=('class', 'sum'),
    )
    .assign(fraud_rate=lambda x: x.frauds / x.transactions)
)

country_stats.sort_values("fraud_rate")
# Out:
#                        transactions  frauds  fraud_rate
# country
# Kyrgyzstan                       18       0    0.000000
# Maldives                          2       0    0.000000
# Madagascar                        1       0    0.000000
# Macau                            10       0    0.000000
# Liechtenstein                     2       0    0.000000
# ...                             ...     ...         ...
# Virgin Islands (U.S.)             3       1    0.333333
# Luxembourg                       72      28    0.388889
# Sri Lanka                        31      13    0.419355
# Namibia                          23      10    0.434783
# Turkmenistan                      1       1    1.000000
#
# [181 rows x 3 columns]

# %%
filtered_country_stats = country_stats[(country_stats['fraud_rate'] > 0.1) & (country_stats["transactions"] > 1)]
plt.figure(figsize=(12,6))
plt.bar(filtered_country_stats.index, filtered_country_stats['fraud_rate'])
plt.xticks(rotation=90)
plt.ylabel('Number of Fraudulent Transactions')
plt.title('Fraudulent Transactions by Country')
plt.show()

# %% [markdown]
# ### Device-IP Consistency
# `device_ip_consistency` ensures that each device is tied to exactly one IP address and vice versa, which is important for tracking legitimate access patterns. If a device is used from multiple IPs or if multiple devices are sharing the same IP, it could raise concerns for system misuse or fraud.
#
# ### User-Level Consistency
# `device_ip_user_consistency` goes a step further by considering user-level consistency. This helps to flag cases where multiple users may be accessing the same device or IP, which could be a sign of account sharing, misconfiguration, or even fraudulent activity.

# %%
# rename transactions_by_device_id and transactions_by_ip_address to users_by_device_id and users_by_ip_address
df = df.rename(columns={'transactions_by_device_id': 'users_by_device_id', 'transactions_by_ip_address': 'users_by_ip_address'})

# %%
def device_ip_counts(df):
    devices_by_ip = df.groupby("ip_address").agg({"device_id":"nunique"}).to_dict()["device_id"]
    ip_by_device = df.groupby("device_id").agg({"ip_address":"nunique"}).to_dict()["ip_address"]

    df["devices_by_ip"] = df["ip_address"].apply(lambda ip: devices_by_ip[ip])
    df["ip_by_device"] = df["device_id"].apply(lambda device_id: ip_by_device[device_id])

    df["device_ip_consistency"] = (df["devices_by_ip"] == 1) & (df["ip_by_device"] == 1)

    df["device_ip_user_consistency"] = (
    (df["device_ip_consistency"]) &
    (df["users_by_ip_address"] == 1) &
    (df["users_by_device_id"] == 1)
)

    return df

# %%
df = device_ip_counts(df)

# %%
df[non_fraud]["device_ip_consistency"].value_counts(normalize=True)
# Out:
# device_ip_consistency
# True     0.937931
# False    0.062069
# Name: proportion, dtype: float64

# %%
df[fraud]["device_ip_consistency"].value_counts(normalize=True)
# Out:
# device_ip_consistency
# True     0.786022
# False    0.213978
# Name: proportion, dtype: float64

# %% [markdown]
# Both fraudulent and non-fraudulent transactions, the vast majority of transactions still maintain `device_ip_consistency`. This suggests that most transactions—whether fraudulent or not—are originating from a single device and IP address.

# %%
df[non_fraud]["device_ip_user_consistency"].value_counts(normalize=True)
# Out:
# device_ip_user_consistency
# True     0.932901
# False    0.067099
# Name: proportion, dtype: float64

# %%
df[fraud]["device_ip_user_consistency"].value_counts(normalize=True)
# Out:
# device_ip_user_consistency
# False    0.716628
# True     0.283372
# Name: proportion, dtype: float64

# %% [markdown]
# Fraudulent transactions exhibit a sharp decline in `device_ip_user_consistency` (only 28.3%).
#
# The drop in consistency for fraudulent transactions is a significant anomaly. It suggests that fraudsters are likely using multiple accounts, possibly from the same device or IP, or engaging in behavior that bypasses standard patterns (e.g., proxy usage, shared devices, etc.).
#
# This discrepancy between normal and fraudulent transactions is a strong indicator of potential fraud, as the fraudulent behavior doesn't follow the same device-IP-user consistency patterns that legitimate transactions do.

# %% [markdown]
# ## Time Between Signup and Purchase

# %%
def signup_purchase_time(df):
    # convert to datetime
    df["signup_time"] = pd.to_datetime(df["signup_time"])
    df["purchase_time"] = pd.to_datetime(df["purchase_time"])

    df["time_between_setup_and_transaction"] = (df["purchase_time"]  - df["signup_time"]).dt.total_seconds()
    
    return df

df = signup_purchase_time(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[139], line 10
#       6     df["time_between_setup_and_transaction"] = (df["purchase_time"]  - df["signup_time"]).dt.total_seconds()
#       8     return df
# ---> 10 df = signup_purchase_time(df)
#
# NameError: name 'df' is not defined

# %%
sns.kdeplot(data=df, x="time_between_setup_and_transaction")
# Out:
# <Axes: xlabel='time_between_setup_and_transaction', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="time_between_setup_and_transaction", hue="class")
# Out:
# <Axes: xlabel='time_between_setup_and_transaction', ylabel='Density'>

# %% [markdown]
# ### Do fraudulent transactions have smaller difference between signup and purchase times than non-fraudulent transactions?
#
# H0: There is no difference
# H1: Fraudulent transactions have smaller (one direction, one-tail) difference between signup and purchase times than non-fraudulent transactions.
#
# Test the hypothesis with Mann-Whitney U test since distribution is not normal. While Mann-Whitney U test assumes that the samples are independent of one another, this may not be the case in the real-world. For example, fraudsters part of the same collusion may be aware of the significance of `time_between_setup_and_transaction` and may intentionally vary this amongst their group.

# %%
from scipy.stats import mannwhitneyu, norm

# %%
def mannwhitneyu_large(df, fraud_idx, non_fraud_idx):
    n1 = fraud_idx.sum()
    n2 = non_fraud_idx.sum()
    
    # Before running the Mann-Whitney U test, make sure you're using efficient data types.
    df['time_between_setup_and_transaction'] = pd.to_numeric(df['time_between_setup_and_transaction'], downcast='float')

    frauds = df[fraud_idx]["time_between_setup_and_transaction"]
    non_frauds = df[non_fraud_idx]["time_between_setup_and_transaction"]

    p_values = []

    U1, p = mannwhitneyu(frauds, non_frauds, method='asymptotic')
    p_values.append(p)

    return p_values

mannwhitneyu_large(df, fraud, non_fraud)
# Out:
# [np.float64(0.0)]

# %%
def time_between_prev_purchase(df, col):
    df = df.sort_values(by=[col, "purchase_time"])
    df[f"time_diff_{col}"] = df.groupby(col)["purchase_time"].diff().dt.seconds
    return df

# %%
df = time_between_prev_purchase(df, "device_id")
df = time_between_prev_purchase(df, "ip_address")

# %%
sns.kdeplot(data=df, x="time_diff_device_id", hue="class")
# Out:
# <Axes: xlabel='time_diff_device_id', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="time_diff_ip_address", hue="class")
# Out:
# <Axes: xlabel='time_diff_ip_address', ylabel='Density'>

# %% [markdown]
# Out of the transactions that use the same device/ip address, how many of them are fraudulent?

# %%
df[df["device_ip_consistency"] == False].groupby("class")["user_id"].count()
# Out:
# class
# 0    8501
# 1    3028
# Name: user_id, dtype: int64

# %%
device_ip_count = df.groupby(["device_id", "ip_address"]).count()

# %%
device_ip_count[device_ip_count["user_id"] > 1]
# Out:
#                             Unnamed: 0  user_id  signup_time  purchase_time  \
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09          11       11           11             11
# AANYBGQSWHRTK 2.707984e+09           8        8            8              8
# ADEDUDCYQMYTI 2.664872e+09          14       14           14             14
# AENUQLGTUHYMS 2.138534e+09           7        7            7              7
# AIGPGDVRDKOKT 3.058136e+09          12       12           12             12
# ...                                ...      ...          ...            ...
# ZYHVSPGHWACPO 1.202929e+09           6        6            6              6
# ZYZQZXBXADPST 2.056130e+09          16       16           16             16
# ZZCAWCKYVMWNH 8.480062e+08           9        9            9              9
# ZZFFPOVMCQVCG 3.323365e+08           7        7            7              7
# ZZQPVRBHRMVYD 1.136982e+09          12       12           12             12
#
#                             purchase_value  source  browser  sex  age  class  \
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09              11      11       11   11   11     11
# AANYBGQSWHRTK 2.707984e+09               8       8        8    8    8      8
# ADEDUDCYQMYTI 2.664872e+09              14      14       14   14   14     14
# AENUQLGTUHYMS 2.138534e+09               7       7        7    7    7      7
# AIGPGDVRDKOKT 3.058136e+09              12      12       12   12   12     12
# ...                                    ...     ...      ...  ...  ...    ...
# ZYHVSPGHWACPO 1.202929e+09               6       6        6    6    6      6
# ZYZQZXBXADPST 2.056130e+09              16      16       16   16   16     16
# ZZCAWCKYVMWNH 8.480062e+08               9       9        9    9    9      9
# ZZFFPOVMCQVCG 3.323365e+08               7       7        7    7    7      7
# ZZQPVRBHRMVYD 1.136982e+09              12      12       12   12   12     12
#
#                             ...  users_by_device_id  users_by_ip_address  \
# device_id     ip_address    ...
# AAAXXOZJRZRAO 1.377849e+09  ...                  11                   11
# AANYBGQSWHRTK 2.707984e+09  ...                   8                    8
# ADEDUDCYQMYTI 2.664872e+09  ...                  14                   14
# AENUQLGTUHYMS 2.138534e+09  ...                   7                    7
# AIGPGDVRDKOKT 3.058136e+09  ...                  12                   12
# ...                         ...                 ...                  ...
# ZYHVSPGHWACPO 1.202929e+09  ...                   6                    6
# ZYZQZXBXADPST 2.056130e+09  ...                  16                   16
# ZZCAWCKYVMWNH 8.480062e+08  ...                   9                    9
# ZZFFPOVMCQVCG 3.323365e+08  ...                   7                    7
# ZZQPVRBHRMVYD 1.136982e+09  ...                  12                   12
#
#                             country  devices_by_ip  ip_by_device  \
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09       11             11            11
# AANYBGQSWHRTK 2.707984e+09        8              8             8
# ADEDUDCYQMYTI 2.664872e+09       14             14            14
# AENUQLGTUHYMS 2.138534e+09        0              7             7
# AIGPGDVRDKOKT 3.058136e+09       12             12            12
# ...                             ...            ...           ...
# ZYHVSPGHWACPO 1.202929e+09        6              6             6
# ZYZQZXBXADPST 2.056130e+09       16             16            16
# ZZCAWCKYVMWNH 8.480062e+08        9              9             9
# ZZFFPOVMCQVCG 3.323365e+08        7              7             7
# ZZQPVRBHRMVYD 1.136982e+09       12             12            12
#
#                             device_ip_consistency  device_ip_user_consistency  \
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09                     11                          11
# AANYBGQSWHRTK 2.707984e+09                      8                           8
# ADEDUDCYQMYTI 2.664872e+09                     14                          14
# AENUQLGTUHYMS 2.138534e+09                      7                           7
# AIGPGDVRDKOKT 3.058136e+09                     12                          12
# ...                                           ...                         ...
# ZYHVSPGHWACPO 1.202929e+09                      6                           6
# ZYZQZXBXADPST 2.056130e+09                     16                          16
# ZZCAWCKYVMWNH 8.480062e+08                      9                           9
# ZZFFPOVMCQVCG 3.323365e+08                      7                           7
# ZZQPVRBHRMVYD 1.136982e+09                     12                          12
#
#                             time_between_setup_and_transaction  \
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09                                  11
# AANYBGQSWHRTK 2.707984e+09                                   8
# ADEDUDCYQMYTI 2.664872e+09                                  14
# AENUQLGTUHYMS 2.138534e+09                                   7
# AIGPGDVRDKOKT 3.058136e+09                                  12
# ...                                                        ...
# ZYHVSPGHWACPO 1.202929e+09                                   6
# ZYZQZXBXADPST 2.056130e+09                                  16
# ZZCAWCKYVMWNH 8.480062e+08                                   9
# ZZFFPOVMCQVCG 3.323365e+08                                   7
# ZZQPVRBHRMVYD 1.136982e+09                                  12
#
#                             time_diff_device_id  time_diff_ip_address
# device_id     ip_address
# AAAXXOZJRZRAO 1.377849e+09                   10                    10
# AANYBGQSWHRTK 2.707984e+09                    7                     7
# ADEDUDCYQMYTI 2.664872e+09                   13                    13
# AENUQLGTUHYMS 2.138534e+09                    6                     6
# AIGPGDVRDKOKT 3.058136e+09                   11                    11
# ...                                         ...                   ...
# ZYHVSPGHWACPO 1.202929e+09                    5                     5
# ZYZQZXBXADPST 2.056130e+09                   15                    15
# ZZCAWCKYVMWNH 8.480062e+08                    8                     8
# ZZFFPOVMCQVCG 3.323365e+08                    6                     6
# ZZQPVRBHRMVYD 1.136982e+09                   11                    11
#
# [760 rows x 21 columns]

# %% [markdown]
# Out of all the devices and IPs that have been reused, how many fraudulent transactions come from each of them?

# %%
def summarize_entity(df, entity_col):
    """
    Summarize fraud and transaction statistics for either device_id or ip_address.

    Parameters
    ----------
    df : pd.DataFrame
        Dataset containing fraud info.
    entity_col : str
        Either 'device_id' or 'ip_address'.

    Returns
    -------
    pd.DataFrame
        Aggregated statistics per entity.
    """
    # Sanity check
    if entity_col not in ['device_id', 'ip_address']:
        raise ValueError("entity_col must be either 'device_id' or 'ip_address'")

    # Determine opposite entity for unique counting
    other_entity = 'ip_address' if entity_col == 'device_id' else 'device_id'
    other_entity_name = 'unique_ips' if entity_col == 'device_id' else 'unique_device_ids'

    # Build aggregation dictionary
    agg_dict = {
        'class': [('transactions', 'count'), ('frauds', 'sum')],
        'user_id': [('unique_users', 'nunique')],
        other_entity: [(other_entity_name, 'nunique')],
        'purchase_value': [('mean_purchase_val', 'mean'),
                           ('purchase_val_std', 'std')],
        # handle missing safely
        'time_between_setup_and_transaction': [('median_time_between_signup_and_purchase', 'median')],
    }

    # Include correct time diff column
    if entity_col == 'device_id':
        time_col = 'time_diff_device_id'
    else:
        time_col = 'time_diff_ip_address'

    agg_dict[time_col] = [('median_time_between_purchase', 'median')]

    # Perform aggregation
    stats = (
        df.groupby(entity_col)
          .agg(agg_dict)
          .reset_index()
    )

    # Flatten MultiIndex columns (from nested aggregation)
    stats.columns = [entity_col] + [c[1] for c in stats.columns[1:]]

    # Add derived metric: fraud rate
    stats['fraud_rate'] = stats['frauds'] / stats['transactions']

    return stats

# %% [markdown]
# median is used for `time_between_purchase` and `time_between_signup_and_purchase` as analysis shows that fraudulent transactions by the same device/id takes place 1s after the previous, and there are transactions that are made by the same device/id that are made way later than the last transaction, and they may not be fraudulent.
#
# For instance,
#
# Device with id 'AAAXXOZJRZRAO' has a fraud_rate of 0.909091.
#
# This device could have been stolen and subsequently used for fraud, or vice versa: Look into when each transaction was made. A clear separation of `purchase_time` suggests that this was a stolen device, otherwise
#
# This device could have been part of an organised fraud ring. Analysing the purchase value of each transaction
# - smaller purchase value for non-fraudulent transactions implies that the fraud ring was testing.
# - small difference between purchase value suggests that it was an attempt to look more discreet.

# %%
# Justification for using median, instead of mean
df[df["device_id"] == "AAAXXOZJRZRAO"][["signup_time", "purchase_time", "purchase_value", "sex", "age", "time_between_setup_and_transaction", "time_diff_device_id", "time_diff_ip_address", "class"]]
# Out:
#                signup_time       purchase_time  purchase_value sex  age  \
# 69175  2015-01-01 04:25:22 2015-01-01 04:25:23              57   F   36
# 35860  2015-01-01 04:25:23 2015-01-01 04:25:24              57   F   36
# 115396 2015-01-01 04:25:24 2015-01-01 04:25:25              57   F   36
# 136484 2015-01-01 04:25:25 2015-01-01 04:25:26              57   F   36
# 44484  2015-01-01 04:25:26 2015-01-01 04:25:27              57   F   36
# 65899  2015-01-01 04:25:27 2015-01-01 04:25:28              57   F   36
# 83494  2015-01-01 04:25:28 2015-01-01 04:25:29              57   F   36
# 56146  2015-01-01 04:25:29 2015-01-01 04:25:30              57   F   36
# 138229 2015-01-01 04:25:30 2015-01-01 04:25:31              57   F   36
# 107401 2015-01-01 04:25:31 2015-01-01 04:25:32              57   F   36
# 97331  2015-01-01 04:25:21 2015-01-28 10:39:35              57   F   36
#
#         time_between_setup_and_transaction  time_diff_device_id  \
# 69175                                  1.0                  NaN
# 35860                                  1.0                  1.0
# 115396                                 1.0                  1.0
# 136484                                 1.0                  1.0
# 44484                                  1.0                  1.0
# 65899                                  1.0                  1.0
# 83494                                  1.0                  1.0
# 56146                                  1.0                  1.0
# 138229                                 1.0                  1.0
# 107401                                 1.0                  1.0
# 97331                            2355254.0              22443.0
#
#         time_diff_ip_address  class
# 69175                    NaN      1
# 35860                    1.0      1
# 115396                   1.0      1
# 136484                   1.0      1
# 44484                    1.0      1
# 65899                    1.0      1
# 83494                    1.0      1
# 56146                    1.0      1
# 138229                   1.0      1
# 107401                   1.0      1
# 97331                22443.0      0

# %%
stats_by_device = summarize_entity(df, "device_id")

# %%
stats_by_device[stats_by_device["transactions"] > 2]
# Out:
#             device_id  transactions  frauds  unique_users  unique_ips  \
# 3       AAAXXOZJRZRAO            11      10            11           1
# 114     AANYBGQSWHRTK             8       7             8           1
# 645     ADEDUDCYQMYTI            14      13            14           1
# 919     AENUQLGTUHYMS             7       6             7           1
# 1733    AIGPGDVRDKOKT            12      11            12           1
# ...               ...           ...     ...           ...         ...
# 137622  ZYHVSPGHWACPO             6       5             6           1
# 137774  ZYZQZXBXADPST            16      15            16           1
# 137790  ZZCAWCKYVMWNH             9       8             9           1
# 137810  ZZFFPOVMCQVCG             7       6             7           1
# 137898  ZZQPVRBHRMVYD            12      11            12           1
#
#         mean_purchase_val  purchase_val_std  \
# 3                    57.0               0.0
# 114                  42.0               0.0
# 645                  52.0               0.0
# 919                  58.0               0.0
# 1733                 21.0               0.0
# ...                   ...               ...
# 137622               59.0               0.0
# 137774               40.0               0.0
# 137790               38.0               0.0
# 137810               21.0               0.0
# 137898               84.0               0.0
#
#         median_time_between_signup_and_purchase  median_time_between_purchase  \
# 3                                           1.0                           1.0
# 114                                         1.0                           1.0
# 645                                         1.0                           1.0
# 919                                         1.0                           1.0
# 1733                                        1.0                           1.0
# ...                                         ...                           ...
# 137622                                      1.0                           1.0
# 137774                                      1.0                           1.0
# 137790                                      1.0                           1.0
# 137810                                      1.0                           1.0
# 137898                                      1.0                           1.0
#
#         fraud_rate
# 3         0.909091
# 114       0.875000
# 645       0.928571
# 919       0.857143
# 1733      0.916667
# ...            ...
# 137622    0.833333
# 137774    0.937500
# 137790    0.888889
# 137810    0.857143
# 137898    0.916667
#
# [848 rows x 10 columns]

# %%
stats_by_device[stats_by_device["transactions"] > 1][["transactions", "mean_purchase_val", "purchase_val_std", "median_time_between_signup_and_purchase", "median_time_between_purchase", "fraud_rate"]].corr()
# Out:
#                                          transactions  mean_purchase_val  \
# transactions                                 1.000000           0.000594
# mean_purchase_val                            0.000594           1.000000
# purchase_val_std                            -0.375089           0.282386
# median_time_between_signup_and_purchase     -0.609412           0.025039
# median_time_between_purchase                -0.488854           0.017430
# fraud_rate                                   0.594005           0.011738
#
#                                          purchase_val_std  \
# transactions                                    -0.375089
# mean_purchase_val                                0.282386
# purchase_val_std                                 1.000000
# median_time_between_signup_and_purchase          0.270543
# median_time_between_purchase                     0.231983
# fraud_rate                                      -0.251574
#
#                                          median_time_between_signup_and_purchase  \
# transactions                                                           -0.609412
# mean_purchase_val                                                       0.025039
# purchase_val_std                                                        0.270543
# median_time_between_signup_and_purchase                                 1.000000
# median_time_between_purchase                                            0.326326
# fraud_rate                                                             -0.400067
#
#                                          median_time_between_purchase  \
# transactions                                                -0.488854
# mean_purchase_val                                            0.017430
# purchase_val_std                                             0.231983
# median_time_between_signup_and_purchase                      0.326326
# median_time_between_purchase                                 1.000000
# fraud_rate                                                  -0.331059
#
#                                          fraud_rate
# transactions                               0.594005
# mean_purchase_val                          0.011738
# purchase_val_std                          -0.251574
# median_time_between_signup_and_purchase   -0.400067
# median_time_between_purchase              -0.331059
# fraud_rate                                 1.000000

# %%
stats_by_device[stats_by_device["transactions"] > 2][["transactions", "mean_purchase_val", "purchase_val_std", "median_time_between_signup_and_purchase", "median_time_between_purchase", "fraud_rate"]].corr()
# Out:
#                                          transactions  mean_purchase_val  \
# transactions                                 1.000000           0.028825
# mean_purchase_val                            0.028825           1.000000
# purchase_val_std                            -0.524666           0.080331
# median_time_between_signup_and_purchase     -0.574132           0.003350
# median_time_between_purchase                -0.594925           0.016315
# fraud_rate                                   0.684414          -0.015026
#
#                                          purchase_val_std  \
# transactions                                    -0.524666
# mean_purchase_val                                0.080331
# purchase_val_std                                 1.000000
# median_time_between_signup_and_purchase          0.736403
# median_time_between_purchase                     0.759093
# fraud_rate                                      -0.784586
#
#                                          median_time_between_signup_and_purchase  \
# transactions                                                           -0.574132
# mean_purchase_val                                                       0.003350
# purchase_val_std                                                        0.736403
# median_time_between_signup_and_purchase                                 1.000000
# median_time_between_purchase                                            0.788026
# fraud_rate                                                             -0.818920
#
#                                          median_time_between_purchase  \
# transactions                                                -0.594925
# mean_purchase_val                                            0.016315
# purchase_val_std                                             0.759093
# median_time_between_signup_and_purchase                      0.788026
# median_time_between_purchase                                 1.000000
# fraud_rate                                                  -0.824332
#
#                                          fraud_rate
# transactions                               0.684414
# mean_purchase_val                         -0.015026
# purchase_val_std                          -0.784586
# median_time_between_signup_and_purchase   -0.818920
# median_time_between_purchase              -0.824332
# fraud_rate                                 1.000000

# %% [markdown]
# Filtering transactions to those where the same device has been used more than 2 times has a significant impact on the relationship between `fraud_rate` and `transactions`, `purchase_val_std`, `median_time_between_signup_and_purchase` and `median_time_between_purchase`
#
# this is consistent with:
# 1. transactions from the same device often have the same `purchase_value`, which means lower `purchase_val_std`
# 2. transactions from the same device that are made one after another are more likely to be fraudulent.
# 3. transactions from the same device that are made not long after account set up aare more likely to be fraudulent

# %%
stats_by_ip = summarize_entity(df, "ip_address")

# %%
stats_by_ip[stats_by_ip["transactions"] > 1]
# Out:
#           ip_address  transactions  frauds  unique_users  unique_device_ids  \
# 68      2.278096e+06            16      15            16                  1
# 223     6.150367e+06             9       9             9                  1
# 598     1.666923e+07            11      10            11                  1
# 649     1.819146e+07             6       5             6                  1
# 928     2.584822e+07             7       6             7                  1
# ...              ...           ...     ...           ...                ...
# 142433  4.262695e+09            13      12            13                  1
# 142856  4.275223e+09            11      10            11                  1
# 142998  4.279796e+09            12      11            12                  1
# 143073  4.281743e+09             7       6             7                  1
# 143438  4.292714e+09             6       5             6                  1
#
#         mean_purchase_val  purchase_val_std  \
# 68                   26.0               0.0
# 223                  30.0               0.0
# 598                  34.0               0.0
# 649                  15.0               0.0
# 928                  27.0               0.0
# ...                   ...               ...
# 142433               43.0               0.0
# 142856               41.0               0.0
# 142998               41.0               0.0
# 143073               54.0               0.0
# 143438               37.0               0.0
#
#         median_time_between_signup_and_purchase  median_time_between_purchase  \
# 68                                          1.0                           1.0
# 223                                         1.0                           1.0
# 598                                         1.0                           1.0
# 649                                         1.0                           1.0
# 928                                         1.0                           1.0
# ...                                         ...                           ...
# 142433                                      1.0                           1.0
# 142856                                      1.0                           1.0
# 142998                                      1.0                           1.0
# 143073                                      1.0                           1.0
# 143438                                      1.0                           1.0
#
#         fraud_rate
# 68        0.937500
# 223       1.000000
# 598       0.909091
# 649       0.833333
# 928       0.857143
# ...            ...
# 142433    0.923077
# 142856    0.909091
# 142998    0.916667
# 143073    0.857143
# 143438    0.833333
#
# [760 rows x 10 columns]

# %%
stats_by_ip[stats_by_ip["transactions"] > 1][["transactions", "mean_purchase_val", "purchase_val_std", "median_time_between_signup_and_purchase", "median_time_between_purchase", "fraud_rate"]].corr()
# Out:
#                                          transactions  mean_purchase_val  \
# transactions                                 1.000000           0.043000
# mean_purchase_val                            0.043000           1.000000
# purchase_val_std                                  NaN                NaN
# median_time_between_signup_and_purchase     -0.104144           0.040350
# median_time_between_purchase                -0.157091           0.045395
# fraud_rate                                   0.725913          -0.009286
#
#                                          purchase_val_std  \
# transactions                                          NaN
# mean_purchase_val                                     NaN
# purchase_val_std                                      NaN
# median_time_between_signup_and_purchase               NaN
# median_time_between_purchase                          NaN
# fraud_rate                                            NaN
#
#                                          median_time_between_signup_and_purchase  \
# transactions                                                           -0.104144
# mean_purchase_val                                                       0.040350
# purchase_val_std                                                             NaN
# median_time_between_signup_and_purchase                                 1.000000
# median_time_between_purchase                                            0.830055
# fraud_rate                                                             -0.352482
#
#                                          median_time_between_purchase  \
# transactions                                                -0.157091
# mean_purchase_val                                            0.045395
# purchase_val_std                                                  NaN
# median_time_between_signup_and_purchase                      0.830055
# median_time_between_purchase                                 1.000000
# fraud_rate                                                  -0.450867
#
#                                          fraud_rate
# transactions                               0.725913
# mean_purchase_val                         -0.009286
# purchase_val_std                                NaN
# median_time_between_signup_and_purchase   -0.352482
# median_time_between_purchase              -0.450867
# fraud_rate                                 1.000000

# %%
stats_by_ip[stats_by_ip["transactions"] > 2][["transactions", "mean_purchase_val", "purchase_val_std", "median_time_between_signup_and_purchase", "median_time_between_purchase", "fraud_rate"]].corr()
# Out:
#                                          transactions  mean_purchase_val  \
# transactions                                 1.000000           0.047499
# mean_purchase_val                            0.047499           1.000000
# purchase_val_std                                  NaN                NaN
# median_time_between_signup_and_purchase           NaN                NaN
# median_time_between_purchase                -0.127369           0.021359
# fraud_rate                                   0.740499           0.005280
#
#                                          purchase_val_std  \
# transactions                                          NaN
# mean_purchase_val                                     NaN
# purchase_val_std                                      NaN
# median_time_between_signup_and_purchase               NaN
# median_time_between_purchase                          NaN
# fraud_rate                                            NaN
#
#                                          median_time_between_signup_and_purchase  \
# transactions                                                                 NaN
# mean_purchase_val                                                            NaN
# purchase_val_std                                                             NaN
# median_time_between_signup_and_purchase                                      NaN
# median_time_between_purchase                                                 NaN
# fraud_rate                                                                   NaN
#
#                                          median_time_between_purchase  \
# transactions                                                -0.127369
# mean_purchase_val                                            0.021359
# purchase_val_std                                                  NaN
# median_time_between_signup_and_purchase                           NaN
# median_time_between_purchase                                 1.000000
# fraud_rate                                                  -0.303297
#
#                                          fraud_rate
# transactions                               0.740499
# mean_purchase_val                          0.005280
# purchase_val_std                                NaN
# median_time_between_signup_and_purchase         NaN
# median_time_between_purchase              -0.303297
# fraud_rate                                 1.000000

# %%
stats_by_device.groupby("transactions")["fraud_rate"].mean()
# Out:
# transactions
# 1     0.030429
# 2     0.229022
# 3     0.244444
# 4     0.625000
# 5     0.800000
# 6     0.827586
# 7     0.860000
# 8     0.875000
# 9     0.888889
# 10    0.898913
# 11    0.908191
# 12    0.918519
# 13    0.921875
# 14    0.927318
# 15    0.923577
# 16    0.934028
# 17    0.936652
# 18    0.938889
# 19    0.947368
# 20    0.950000
# Name: fraud_rate, dtype: float64

# %%
stats_by_ip.groupby("transactions")["fraud_rate"].mean()
# Out:
# transactions
# 1     0.045653
# 2     0.500000
# 3     0.666667
# 4     0.812500
# 5     0.800000
# 6     0.838889
# 7     0.865714
# 8     0.878521
# 9     0.897019
# 10    0.902247
# 11    0.914545
# 12    0.920330
# 13    0.927885
# 14    0.932203
# 15    0.933333
# 16    0.939236
# 17    0.941176
# 18    0.944444
# 19    0.954887
# 20    0.950000
# Name: fraud_rate, dtype: float64

# %% [markdown]
# Device and IP reuse are useful indicators of fraud. Specifically, the more times a device/IP has been reused, the more likely the transaction made is fraudulent.
#
# - useful feature: number of times device/ip has been reused up till purchase time (helps to decrease data leaking)

# %% [markdown]
# ## Are `source` and `engine` indications of fraud?

# %%
df[non_fraud]["source"].value_counts(normalize=True)
# Out:
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/2360036379.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[non_fraud]["source"].value_counts(normalize=True)
# source
# SEO       0.403056
# Ads       0.396960
# Direct    0.199984
# Name: proportion, dtype: float64

# %%
df[fraud]["source"].value_counts(normalize=True)
# Out:
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/3592328002.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[fraud]["source"].value_counts(normalize=True)
# source
# Ads       0.389584
# SEO       0.382446
# Direct    0.227970
# Name: proportion, dtype: float64

# %% [markdown]
# Do certain interactions between `source` and `browser` have higher fraud risk?

# %%
combo_stats = (
    df.groupby(['source','browser'])
    .agg(
          transactions=('class', 'count'),
          frauds=('class', 'sum')
        )
      .assign(fraud_rate=lambda x: x.frauds / x.transactions)
)
combo_stats
# Out:
#                 transactions  frauds  fraud_rate
# source browser
# Ads    Chrome          24309    2411    0.099181
#        FireFox          9832     914    0.092962
#        IE              14578    1234    0.084648
#        Opera            1413     100    0.070771
#        Safari           9749     854    0.087599
# Direct Chrome          12726    1501    0.117948
#        FireFox          4829     437    0.090495
#        IE               7444     749    0.100618
#        Opera             735      82    0.111565
#        Safari           4882     457    0.093609
# SEO    Chrome          24397    2157    0.088413
#        FireFox          9949     991    0.099608
#        IE              14705    1204    0.081877
#        Opera            1528     146    0.095550
#        Safari          10036     914    0.091072

# %% [markdown]
# since `fraud_rate` is relatively consistent among source-browser pairs, it may not be an insightful feature

# %%
sns.kdeplot(data=df[fraud], x="purchase_value")
# Out:
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/2460997860.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.kdeplot(data=df[fraud], x="purchase_value")
# <Axes: xlabel='purchase_value', ylabel='Density'>

# %%
sns.kdeplot(data=df[non_fraud], x="purchase_value")
# Out:
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_14070/913482835.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.kdeplot(data=df[non_fraud], x="purchase_value")
# <Axes: xlabel='purchase_value', ylabel='Density'>

# %%
import pandas as pd

# Aggregate purchase_value by device_id
device_stats = df.groupby('device_id')['purchase_value'].agg(
    total_value='sum',
    mean_value='mean',
    median_value='median',
    min_value='min',
    max_value='max',
    std_value='std',
    count='count'
).reset_index()

device_stats[device_stats["std_value"] > 0].sort_values(["max_value", "std_value"], ascending=False)
# Out:
#             device_id  total_value  mean_value  median_value  min_value  \
# 40039   HPPPURWQPXJUG          144   72.000000          72.0         16
# 107657  UHULJOWDWFCDT          134   67.000000          67.0          9
# 96240   SDKPJUAARGGBM          136   68.000000          68.0         21
# 35985   GUYJEOMVXXHHK          125   62.500000          62.5         12
# 67739   MVVFZQTTYUVVT          145   72.500000          72.5         34
# ...               ...          ...         ...           ...        ...
# 30075   FRNHHKYPEDMKC           20   10.000000          10.0          9
# 82943   PQYGRFTPGOLHI           20   10.000000          10.0          9
# 137391  ZWZQCBJCNZFOY           20   10.000000          10.0          9
# 86833   QKGYWSCYLQVNG           21   10.500000          10.5         10
# 99592   SUEKLSZWLASFR          169    9.941176          10.0          9
#
#         max_value  std_value  count
# 40039         128  79.195959      2
# 107657        125  82.024387      2
# 96240         115  66.468037      2
# 35985         113  71.417785      2
# 67739         111  54.447222      2
# ...           ...        ...    ...
# 30075          11   1.414214      2
# 82943          11   1.414214      2
# 137391         11   1.414214      2
# 86833          11   0.707107      2
# 99592          10   0.242536     17
#
# [5387 rows x 8 columns]

# %%
device_stats[device_stats["count"]==20]
# Out:
#             device_id  total_value  mean_value  median_value  min_value  \
# 14100   CQTUVBYIWWWBC          644       32.20          32.0         32
# 24607   EQYVNEGOFLAWK         1369       68.45          67.0         67
# 46203   ITUMJCKWEYNDD          760       38.00          38.0         38
# 54521   KIPFSCNUGOLDP         1160       58.00          58.0         58
# 69916   NGQCKIADMZORL          840       42.00          42.0         42
# 136873  ZUSVMDEZRBDTX          940       47.00          47.0         47
#
#         max_value  std_value  count
# 14100          36   0.894427     20
# 24607          96   6.484597     20
# 46203          38   0.000000     20
# 54521          58   0.000000     20
# 69916          42   0.000000     20
# 136873         47   0.000000     20

# %%
df[df["device_id"] == "KIPFSCNUGOLDP"]
# Out:
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 45375        45375   221913 2015-01-03 10:47:31 2015-01-03 10:47:32
# 100762      100762    45046 2015-01-03 10:47:32 2015-01-03 10:47:33
# 91458        91458   168557 2015-01-03 10:47:33 2015-01-03 10:47:34
# 112251      112251   123600 2015-01-03 10:47:34 2015-01-03 10:47:35
# 112822      112822      866 2015-01-03 10:47:35 2015-01-03 10:47:36
# 40300        40300   289750 2015-01-03 10:47:36 2015-01-03 10:47:37
# 133124      133124   228507 2015-01-03 10:47:37 2015-01-03 10:47:38
# 75008        75008   124779 2015-01-03 10:47:38 2015-01-03 10:47:39
# 2070          2070   103009 2015-01-03 10:47:39 2015-01-03 10:47:40
# 148149      148149   255957 2015-01-03 10:47:40 2015-01-03 10:47:41
# 106050      106050    62239 2015-01-03 10:47:41 2015-01-03 10:47:42
# 101060      101060   199343 2015-01-03 10:47:42 2015-01-03 10:47:43
# 3242          3242   340765 2015-01-03 10:47:43 2015-01-03 10:47:44
# 8451          8451   274333 2015-01-03 10:47:44 2015-01-03 10:47:45
# 38361        38361   167569 2015-01-03 10:47:45 2015-01-03 10:47:46
# 63636        63636    34111 2015-01-03 10:47:46 2015-01-03 10:47:47
# 129717      129717   306702 2015-01-03 10:47:47 2015-01-03 10:47:48
# 111644      111644    74754 2015-01-03 10:47:48 2015-01-03 10:47:49
# 121866      121866   159611 2015-01-03 10:47:49 2015-01-03 10:47:50
# 5614          5614   227662 2015-01-03 10:47:30 2015-01-11 19:41:02
#
#         purchase_value      device_id source browser sex  age  ...  \
# 45375               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 100762              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 91458               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 112251              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 112822              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 40300               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 133124              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 75008               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 2070                58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 148149              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 106050              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 101060              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 3242                58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 8451                58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 38361               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 63636               58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 129717              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 111644              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 121866              58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
# 5614                58  KIPFSCNUGOLDP    SEO  Safari   F   36  ...
#
#         users_by_device_id  users_by_ip_address        country  devices_by_ip  \
# 45375                   20                   20  United States              1
# 100762                  20                   20  United States              1
# 91458                   20                   20  United States              1
# 112251                  20                   20  United States              1
# 112822                  20                   20  United States              1
# 40300                   20                   20  United States              1
# 133124                  20                   20  United States              1
# 75008                   20                   20  United States              1
# 2070                    20                   20  United States              1
# 148149                  20                   20  United States              1
# 106050                  20                   20  United States              1
# 101060                  20                   20  United States              1
# 3242                    20                   20  United States              1
# 8451                    20                   20  United States              1
# 38361                   20                   20  United States              1
# 63636                   20                   20  United States              1
# 129717                  20                   20  United States              1
# 111644                  20                   20  United States              1
# 121866                  20                   20  United States              1
# 5614                    20                   20  United States              1
#
#         ip_by_device device_ip_consistency  device_ip_user_consistency  \
# 45375              1                  True                       False
# 100762             1                  True                       False
# 91458              1                  True                       False
# 112251             1                  True                       False
# 112822             1                  True                       False
# 40300              1                  True                       False
# 133124             1                  True                       False
# 75008              1                  True                       False
# 2070               1                  True                       False
# 148149             1                  True                       False
# 106050             1                  True                       False
# 101060             1                  True                       False
# 3242               1                  True                       False
# 8451               1                  True                       False
# 38361              1                  True                       False
# 63636              1                  True                       False
# 129717             1                  True                       False
# 111644             1                  True                       False
# 121866             1                  True                       False
# 5614               1                  True                       False
#
#         time_between_setup_and_transaction  time_diff_device_id  \
# 45375                                  1.0                  NaN
# 100762                                 1.0                  1.0
# 91458                                  1.0                  1.0
# 112251                                 1.0                  1.0
# 112822                                 1.0                  1.0
# 40300                                  1.0                  1.0
# 133124                                 1.0                  1.0
# 75008                                  1.0                  1.0
# 2070                                   1.0                  1.0
# 148149                                 1.0                  1.0
# 106050                                 1.0                  1.0
# 101060                                 1.0                  1.0
# 3242                                   1.0                  1.0
# 8451                                   1.0                  1.0
# 38361                                  1.0                  1.0
# 63636                                  1.0                  1.0
# 129717                                 1.0                  1.0
# 111644                                 1.0                  1.0
# 121866                                 1.0                  1.0
# 5614                              723212.0              31992.0
#
#         time_diff_ip_address
# 45375                    NaN
# 100762                   1.0
# 91458                    1.0
# 112251                   1.0
# 112822                   1.0
# 40300                    1.0
# 133124                   1.0
# 75008                    1.0
# 2070                     1.0
# 148149                   1.0
# 106050                   1.0
# 101060                   1.0
# 3242                     1.0
# 8451                     1.0
# 38361                    1.0
# 63636                    1.0
# 129717                   1.0
# 111644                   1.0
# 121866                   1.0
# 5614                 31992.0
#
# [20 rows x 23 columns]

# %%
df[df["device_id"] == "CQTUVBYIWWWBC"]
# Out:
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 100992      100992   366976 2015-01-04 15:01:47 2015-01-04 15:01:48
# 135302      135302   266507 2015-01-04 15:01:48 2015-01-04 15:01:49
# 7734          7734   109461 2015-01-04 15:01:49 2015-01-04 15:01:50
# 137947      137947   330014 2015-01-04 15:01:50 2015-01-04 15:01:51
# 150265      150265    46958 2015-01-04 15:01:51 2015-01-04 15:01:52
# 50877        50877   293871 2015-01-04 15:01:52 2015-01-04 15:01:53
# 67351        67351    29567 2015-01-04 15:01:53 2015-01-04 15:01:54
# 28035        28035    66663 2015-01-04 15:01:54 2015-01-04 15:01:55
# 12607        12607    21149 2015-01-04 15:01:55 2015-01-04 15:01:56
# 116535      116535   368124 2015-01-04 15:01:56 2015-01-04 15:01:57
# 61756        61756   290353 2015-01-04 15:01:57 2015-01-04 15:01:58
# 113758      113758   305358 2015-01-04 15:01:58 2015-01-04 15:01:59
# 139772      139772     5162 2015-01-04 15:01:59 2015-01-04 15:02:00
# 88633        88633    30488 2015-01-04 15:02:00 2015-01-04 15:02:01
# 106188      106188   226836 2015-01-04 15:02:01 2015-01-04 15:02:02
# 114419      114419   130033 2015-01-04 15:02:02 2015-01-04 15:02:03
# 137816      137816   228375 2015-01-04 15:02:03 2015-01-04 15:02:04
# 56834        56834    65147 2015-01-04 15:02:04 2015-01-04 15:02:05
# 9807          9807    35646 2015-01-04 15:01:46 2015-01-16 08:22:37
# 128584      128584   118353 2015-06-29 19:25:32 2015-10-24 22:10:31
#
#         purchase_value      device_id source browser sex  age  ...  \
# 100992              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 135302              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 7734                32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 137947              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 150265              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 50877               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 67351               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 28035               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 12607               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 116535              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 61756               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 113758              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 139772              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 88633               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 106188              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 114419              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 137816              32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 56834               32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 9807                32  CQTUVBYIWWWBC    SEO      IE   F   42  ...
# 128584              36  CQTUVBYIWWWBC    SEO  Chrome   F   49  ...
#
#         users_by_device_id  users_by_ip_address         country  \
# 100992                  20                   19   United States
# 135302                  20                   19   United States
# 7734                    20                   19   United States
# 137947                  20                   19   United States
# 150265                  20                   19   United States
# 50877                   20                   19   United States
# 67351                   20                   19   United States
# 28035                   20                   19   United States
# 12607                   20                   19   United States
# 116535                  20                   19   United States
# 61756                   20                   19   United States
# 113758                  20                   19   United States
# 139772                  20                   19   United States
# 88633                   20                   19   United States
# 106188                  20                   19   United States
# 114419                  20                   19   United States
# 137816                  20                   19   United States
# 56834                   20                   19   United States
# 9807                    20                   19   United States
# 128584                  20                    1  Czech Republic
#
#         devices_by_ip  ip_by_device device_ip_consistency  \
# 100992              1             2                 False
# 135302              1             2                 False
# 7734                1             2                 False
# 137947              1             2                 False
# 150265              1             2                 False
# 50877               1             2                 False
# 67351               1             2                 False
# 28035               1             2                 False
# 12607               1             2                 False
# 116535              1             2                 False
# 61756               1             2                 False
# 113758              1             2                 False
# 139772              1             2                 False
# 88633               1             2                 False
# 106188              1             2                 False
# 114419              1             2                 False
# 137816              1             2                 False
# 56834               1             2                 False
# 9807                1             2                 False
# 128584              1             2                 False
#
#         device_ip_user_consistency  time_between_setup_and_transaction  \
# 100992                       False                                 1.0
# 135302                       False                                 1.0
# 7734                         False                                 1.0
# 137947                       False                                 1.0
# 150265                       False                                 1.0
# 50877                        False                                 1.0
# 67351                        False                                 1.0
# 28035                        False                                 1.0
# 12607                        False                                 1.0
# 116535                       False                                 1.0
# 61756                        False                                 1.0
# 113758                       False                                 1.0
# 139772                       False                                 1.0
# 88633                        False                                 1.0
# 106188                       False                                 1.0
# 114419                       False                                 1.0
# 137816                       False                                 1.0
# 56834                        False                                 1.0
# 9807                         False                           1012851.0
# 128584                       False                          10118699.0
#
#         time_diff_device_id  time_diff_ip_address
# 100992                  NaN                   NaN
# 135302                  1.0                   1.0
# 7734                    1.0                   1.0
# 137947                  1.0                   1.0
# 150265                  1.0                   1.0
# 50877                   1.0                   1.0
# 67351                   1.0                   1.0
# 28035                   1.0                   1.0
# 12607                   1.0                   1.0
# 116535                  1.0                   1.0
# 61756                   1.0                   1.0
# 113758                  1.0                   1.0
# 139772                  1.0                   1.0
# 88633                   1.0                   1.0
# 106188                  1.0                   1.0
# 114419                  1.0                   1.0
# 137816                  1.0                   1.0
# 56834                   1.0                   1.0
# 9807                62432.0               62432.0
# 128584              49674.0                   NaN
#
# [20 rows x 23 columns]

# %%
purchase_value_by_device_count = device_stats.groupby("count")["mean_value"].mean()
purchase_value_std_by_device_count = device_stats.groupby("count")["std_value"].mean()

# %%
purchase_value_by_device_count
# Out:
# count
# 1     36.928867
# 2     37.005819
# 3     37.622222
# 4     38.312500
# 5     32.507692
# 6     34.971264
# 7     34.828571
# 8     34.871377
# 9     39.252137
# 10    36.468478
# 11    34.423942
# 12    38.137963
# 13    37.907452
# 14    35.136591
# 15    37.668293
# 16    39.336806
# 17    33.208145
# 18    45.927778
# 19    30.800000
# 20    47.608333
# Name: mean_value, dtype: float64

# %%
purchase_value_std_by_device_count
# Out:
# count
# 1           NaN
# 2     14.345494
# 3     16.800396
# 4      4.130047
# 5      0.619219
# 6      0.520869
# 7      0.294812
# 8      0.210082
# 9      0.282051
# 10     0.360912
# 11     0.119410
# 12     0.336788
# 13     0.372689
# 14     0.595477
# 15     1.026498
# 16     0.529070
# 17     1.212678
# 18     0.306413
# 19     0.000000
# 20     1.229837
# Name: std_value, dtype: float64

# %%
sns.kdeplot(data=df, x="purchase_time", hue="class")
# Out:
# <Axes: xlabel='purchase_time', ylabel='Density'>

# %% [markdown]
# Most of the fraudulent transactions were made in the early 2015, while non-fraudulent transactions peaked between 2015-04 to 2015-09

# %% [markdown]
# ## Profile Customers by Clustering them based on:
# - `sex`
# - `age`
# - `purchase_value`
# - `gdp`

# %% [markdown]
# ### Add `gdp` Column
# - GDP by country and year data found at: https://datacatalog.worldbank.org/search/dataset/0037798

# %%
country_gdp_2015 = pd.read_excel("../data/gdp_usd.xlsx", index_col=0).loc[2015.0,].to_dict()

# %%
def caculate_country_mean():
    counts = 0
    value = 0
    for country, gdp in country_gdp_2015.items():
        if "EMDE" not in country or "Countries" not in country or country != "World (WBG members)":
            if not pd.isna(gdp):
                counts += 1
                value += gdp

    return value / counts

impute_value = caculate_country_mean()

# %%
impute_value
# Out:
# 3040975.7022815538

# %%
df["gdp"] = df["country"].apply(lambda x: country_gdp_2015.get(x, np.nan) if x else np.nan)

# %%
df["gdp"].value_counts(dropna=False)
# Out:
# gdp
# 18295100.00    58049
# NaN            31174
# 11163825.00    12038
# 4446613.00      7306
# 2930444.00      4490
#                ...
# 21139.57           9
# 14943.16           7
# 11621.52           6
# 32186.51           5
# 13566.61           3
# Name: count, Length: 84, dtype: int64

# %%
df[df["gdp"].isna()].country.value_counts().index
# Out:
# Index(['Korea Republic of', 'Taiwan; Republic of China (ROC)', 'Viet Nam',
#        'Hong Kong', 'Iran (ISLAMIC Republic Of)', 'Egypt', 'Venezuela',
#        'European Union', 'Pakistan', 'Algeria', 'United Arab Emirates',
#        'Seychelles', 'Slovakia (SLOVAK Republic)',
#        'Croatia (LOCAL Name: Hrvatska)', 'Panama', 'Dominican Republic',
#        'Oman', 'Bangladesh', 'Moldova Republic of', 'Puerto Rico',
#        'Bosnia and Herzegowina', 'Lebanon', 'Qatar', 'Sudan', 'Macedonia',
#        'Angola', 'Syrian Arab Republic', 'Azerbaijan', 'Namibia',
#        'Trinidad and Tobago', 'Iraq', 'Nepal', 'Kyrgyzstan',
#        'Palestinian Territory Occupied', 'Mozambique', 'Cambodia', 'Rwanda',
#        'Tanzania United Republic of', 'Libyan Arab Jamahiriya', 'Uganda',
#        'Zambia', 'Macau', 'Gabon', 'Cuba', 'Barbados', 'Senegal', 'Belize',
#        'Malawi', 'Brunei Darussalam', 'Guam', 'Montenegro', 'Zimbabwe',
#        'Afghanistan', 'Cote D'ivoire', 'New Caledonia', 'Papua New Guinea',
#        'Lao People's Democratic Republic', 'Bahamas', 'Cayman Islands',
#        'Haiti', 'Ethiopia', 'Faroe Islands', 'Monaco', 'Antigua and Barbuda',
#        'Virgin Islands (U.S.)', 'Reunion', 'Congo', 'Curacao', 'Djibouti',
#        'Congo The Democratic Republic of The', 'Bermuda', 'Gibraltar',
#        'Lesotho', 'Saint Kitts and Nevis', 'Liechtenstein', 'Maldives',
#        'Bhutan', 'Fiji', 'Burkina Faso', 'Benin', 'Madagascar',
#        'British Indian Ocean Territory', 'Vanuatu', 'Cape Verde', 'Gambia',
#        'Niger', 'Burundi', 'Saint Martin', 'South Sudan', 'San Marino',
#        'Turkmenistan', 'Yemen', 'Dominica', 'Bonaire; Sint Eustatius; Saba',
#        'Myanmar', 'Tajikistan', 'Guadeloupe', 'Nauru'],
#       dtype='object', name='country')

# %% [markdown]
# ### Refine mapping of gdp to country by Normalising Country Names

# %%
country_map = {
    "Korea Republic of": "Korea, Rep.",
    "Taiwan; Republic of China (ROC)": "Taiwan, China",
    "Hong Kong": "Hong Kong SAR, China",
    "Egypt": "Egypt, Arab Rep.",
    "Slovakia": "Slovakia (SLOVAK Republic)",
    "Croatia": "Croatia (LOCAL Name: Hrvatska)",
    "Oman": "EMDE Middle East, North Africa, Afghanistan & Pakistan",
    "Moldova Republic of": "Moldova, Rep.",
    "Bosnia and Herzegowina": "Bosnia and Herzegovina",
    "Macedonia": "North Macedonia"
}

def get_country_gdp(country):
    if country not in country_gdp_2015 and country in country_map:
        print(country)
        country = country_map[country]
    
    return country_gdp_2015.get(country, np.nan)

# %%
df["gdp"] = df["country"].apply(
    lambda x: country_gdp_2015.get(x, country_gdp_2015.get(country_map.get(x))) if x in country_gdp_2015 or x in country_map else impute_value
)

# %% [markdown]
# K = 16 was chosen based on intuitive segmentation across four binary-like dimensions (age, spending, GDP, gender), producing interpretable customer groups such as “Young High Spenders from High-GDP countries” or “Older Low Spenders from Low-GDP regions.”

# %%
from kneed import KneeLocator
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import DBSCAN, KMeans
from sklearn.neighbors import NearestNeighbors

def dbscan_search(features):
    neighbours = NearestNeighbors(n_neighbors=5)
    neighbours_fit = neighbours.fit(features)
    distances, indices = neighbours_fit.kneighbors(features)

    # Sort the distances to find the “knee”
    distances = np.sort(distances[:, -1])
    plt.plot(distances)
    plt.xlabel("Points sorted by distance")
    plt.ylabel("8th Nearest Neighbor Distance")
    plt.title("Elbow Method for DBSCAN Epsilon")
    plt.show()

    knee = KneeLocator(range(len(distances)), distances, curve="convex", direction="increasing")
    eps_optimal = distances[knee.knee]
    return eps_optimal

def cluster_customers(df, clustering_model, *features):
    cluster_df = df.copy()[["sex", "purchase_value", "age", "gdp"]]

    numeric = ["age", "purchase_value", "gdp"]
    categorical = ["sex"]

    preprocessor = ColumnTransformer([
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ])

    X = preprocessor.fit_transform(cluster_df)

    if clustering_model == "DBSCAN":
        # 2 <= min_samples <= 2 * dim
        eps = dbscan_search(X)
        model = DBSCAN(eps, min_samples=2*4)
    elif clustering_model == "KMeans":
        model = KMeans(n_clusters=16, random_state=42)

    labels = model.fit_predict(X)
    return X, labels

# %%
X, dbscan_labels = cluster_customers(df, "DBSCAN")
_, kmeans_labels = cluster_customers(df, "KMeans")

# %% [markdown]
# ### Evaluate Clustering Performance
#
# Silhouette Score
# - Measures how similar a data point is to its own cluster compared to other clusters.
# - Ranges from -1 to 1, where 1 indicates well-separated and dense clusters, 0 indicates overlapping clusters, and -1 suggests incorrect assignments.

# %%
from sklearn.metrics import silhouette_score

print("Silhouette (K-Means):", silhouette_score(X, kmeans_labels))
print("Silhouette (DBSCAN):", silhouette_score(X, dbscan_labels))
# Out:
# Silhouette (K-Means): 0.24005536690923163
# Silhouette (DBSCAN): 0.13747737364517457

# %% [markdown]
# Visualisation
# - Project features used for clustering into a 2D space
# - Plot graph of PCA feature 1 against PCA feature 2, and colour by cluster labels

# %%
from sklearn.decomposition import PCA

def visualise_clusters_pca(X, labels):
    pca = PCA(2)
    X_pca = pca.fit_transform(X)

    plt.figure(figsize=(8,4))
    plt.scatter(X_pca[:,0], X_pca[:,1], c=labels, cmap='rainbow', s=5)
    plt.title('DBSCAN Clusters')
    plt.show()

# %%
visualise_clusters_pca(X, kmeans_labels)

# %%
visualise_clusters_pca(X, dbscan_labels)

# %%
df["customer_group"] = kmeans_labels

# %%
df["is_male"] = df["sex"].apply(lambda x: 1 if x == "M" else 0)

# %%
df.groupby("customer_group")[["purchase_value", "age", "gdp", "is_male"]].mean()
# Out:
#                 purchase_value        age           gdp   is_male
# customer_group
# 0                    60.504352  44.075692  2.465476e+06  0.549270
# 1                    21.710288  36.271243  2.240962e+06  1.000000
# 2                    53.058195  41.253959  1.723715e+07  0.589818
# 3                    41.786376  27.426646  1.707723e+07  0.000000
# 4                    48.327237  23.765183  2.267826e+06  0.601663
# 5                    29.018008  48.691839  2.197305e+06  0.670346
# 6                    72.921289  29.595704  2.224688e+06  0.574062
# 7                    45.202785  34.496652  2.201451e+06  0.668696
# 8                    20.027372  24.589761  1.701850e+07  0.613500
# 9                    42.794461  27.511176  1.709754e+07  1.000000
# 10                   22.286751  36.010071  1.708495e+07  0.594167
# 11                   70.996141  28.985644  1.706325e+07  0.583205
# 12                   23.798448  38.098022  2.212858e+06  0.000000
# 13                   26.613463  47.488531  1.706144e+07  0.576324
# 14                   23.081625  25.052879  2.190119e+06  1.000000
# 15                   23.744769  26.066476  2.208660e+06  0.000000

# %% [markdown]
# ## Investigating the timing of transactions
#
# ### month
# - is there a particular period where more fraudulent transactions take place?
#
# ### day of the week
# - are fraudulent transactions more likely to take place on the weekdays than the weekends?
#
# ### hour
# - are fraudulent transactions more likely to take place at irregular hours?

# %%
df["purchase_month"] = df["purchase_time"].apply(lambda x: x.month)
df["purchase_day"] = df["purchase_time"].apply(lambda x: x.weekday())
df["purchase_hour"] = df["purchase_time"].apply(lambda x: x.hour)

# %%
df.groupby("class")["purchase_month"].value_counts(normalize=True)
# Out:
# class  purchase_month
# 0      7                 0.135856
#        5                 0.134659
#        6                 0.131906
#        8                 0.130176
#        4                 0.115442
#        9                 0.099912
#        3                 0.084294
#        10                0.068436
#        2                 0.044962
#        11                0.033053
#        1                 0.017333
#        12                0.003972
# 1      1                 0.545756
#        5                 0.065084
#        7                 0.063600
#        6                 0.059501
#        8                 0.058865
#        4                 0.052293
#        9                 0.046852
#        3                 0.038513
#        10                0.031235
#        2                 0.020564
#        11                0.015264
#        12                0.002473
# Name: proportion, dtype: float64

# %%
df.groupby("purchase_month")["class"].value_counts(normalize=True)
# Out:
# purchase_month  class
# 1               1        0.764881
#                 0        0.235119
# 2               0        0.954877
#                 1        0.045123
# 3               0        0.954921
#                 1        0.045079
# 4               0        0.955290
#                 1        0.044710
# 5               0        0.952438
#                 1        0.047562
# 6               0        0.955469
#                 1        0.044531
# 7               0        0.953863
#                 1        0.046137
# 8               0        0.955364
#                 1        0.044636
# 9               0        0.953788
#                 1        0.046212
# 10              0        0.954967
#                 1        0.045033
# 11              0        0.954459
#                 1        0.045541
# 12              0        0.939551
#                 1        0.060449
# Name: proportion, dtype: float64

# %% [markdown]
# 1. The number of actual transactions is consistent, while for fraudulent transactions, there was a spike in the number of transactions in January
# 2. About 5% of the transactions each month were fraudulent, except in January where 76% of the transactions were fraudulent.

# %%
df.groupby("class")["purchase_day"].value_counts(normalize=True)
# Out:
# class  purchase_day
# 0      6               0.144516
#        1               0.143435
#        0               0.143267
#        2               0.143143
#        5               0.142369
#        3               0.142135
#        4               0.141135
# 1      6               0.157021
#        4               0.154901
#        5               0.151862
#        3               0.149742
#        0               0.147622
#        2               0.120910
#        1               0.117942
# Name: proportion, dtype: float64

# %%
df.groupby("purchase_day")["class"].value_counts(normalize=True)
# Out:
# purchase_day  class
# 0             0        0.903781
#               1        0.096219
# 1             0        0.921695
#               1        0.078305
# 2             0        0.919732
#               1        0.080268
# 3             0        0.901835
#               1        0.098165
# 4             0        0.898151
#               1        0.101849
# 5             0        0.900730
#               1        0.099270
# 6             0        0.899069
#               1        0.100931
# Name: proportion, dtype: float64

# %%
df.groupby("class")["purchase_hour"].value_counts(normalize=True)
# Out:
# class  purchase_hour
# 0      3                0.042669
#        22               0.042457
#        12               0.042341
#        6                0.042246
#        17               0.042136
#        11               0.042078
#        2                0.042019
#        14               0.041983
#        8                0.041902
#        9                0.041902
#        15               0.041895
#        23               0.041859
#        13               0.041771
#        20               0.041705
#        19               0.041537
#        16               0.041515
#        1                0.041384
#        21               0.041304
#        18               0.041282
#        7                0.041150
#        0                0.041128
#        5                0.041128
#        4                0.040508
#        10               0.040099
# 1      17               0.049113
#        9                0.047982
#        8                0.045792
#        15               0.044590
#        16               0.044025
#        3                0.043389
#        19               0.043106
#        10               0.042965
#        14               0.042753
#        12               0.042682
#        18               0.042258
#        6                0.041976
#        23               0.041623
#        2                0.041199
#        13               0.040351
#        21               0.040068
#        11               0.039856
#        1                0.039573
#        5                0.039291
#        0                0.039079
#        7                0.038513
#        22               0.038372
#        20               0.035969
#        4                0.035475
# Name: proportion, dtype: float64

# %%
df.groupby("purchase_hour")["class"].value_counts(normalize=True)
# Out:
# purchase_hour  class
# 0              0        0.910605
#                1        0.089395
# 1              0        0.910083
#                1        0.089917
# 2              0        0.908015
#                1        0.091985
# 3              0        0.904924
#                1        0.095076
# 4              0        0.917025
#                1        0.082975
# 5              0        0.910163
#                1        0.089837
# 6              0        0.906897
#                1        0.093103
# 7              0        0.911827
#                1        0.088173
# 8              0        0.898544
#                1        0.101456
# 9              0        0.894204
#                1        0.105796
# 10             0        0.900328
#                1        0.099672
# 11             0        0.910858
#                1        0.089142
# 12             0        0.905669
#                1        0.094331
# 13             0        0.909250
#                1        0.090750
# 14             0        0.904799
#                1        0.095201
# 15             0        0.900926
#                1        0.099074
# 16             0        0.901252
#                1        0.098748
# 17             0        0.892515
#                1        0.107485
# 18             0        0.904351
#                1        0.095649
# 19             0        0.903159
#                1        0.096841
# 20             0        0.918180
#                1        0.081820
# 21             0        0.908901
#                1        0.091099
# 22             0        0.914596
#                1        0.085404
# 23             0        0.906833
#                1        0.093167
# Name: proportion, dtype: float64

# %% [markdown]
# The day of the week and time of the day has a negligible impact on fraudulent behaviour.

# %% [markdown]
# ### Does the `purchase_value` of a transaction vary with when it was made?

# %%
df.groupby("purchase_month")["purchase_value"].mean()
# Out:
# purchase_month
# 1     36.783005
# 2     36.627694
# 3     36.709098
# 4     36.840976
# 5     36.969273
# 6     37.151417
# 7     36.800943
# 8     37.089326
# 9     37.138566
# 10    36.905349
# 11    36.777145
# 12    38.590674
# Name: purchase_value, dtype: float64

# %%
df.groupby("purchase_day")["purchase_value"].mean()
# Out:
# purchase_day
# 0    36.906591
# 1    37.092334
# 2    36.937230
# 3    36.688919
# 4    36.945405
# 5    37.179000
# 6    36.802271
# Name: purchase_value, dtype: float64

# %%
df.groupby("purchase_hour")["purchase_value"].mean()
# Out:
# purchase_hour
# 0     36.495635
# 1     36.775690
# 2     36.365888
# 3     36.457107
# 4     37.161488
# 5     37.180805
# 6     36.986364
# 7     37.033166
# 8     36.846094
# 9     37.371611
# 10    37.195738
# 11    36.915600
# 12    36.764798
# 13    37.270979
# 14    37.082769
# 15    36.832784
# 16    36.551434
# 17    36.947417
# 18    37.376520
# 19    37.102556
# 20    37.240154
# 21    37.047558
# 22    36.848852
# 23    36.633186
# Name: purchase_value, dtype: float64

# %% [markdown]
# ### Feature Selection and Transformation Summary
#
# For the supervised fraud detection model, the following features have been selected and preprocessed to balance **signal strength**, **interpretability**, and **model readiness**:
#
# | Feature                                                                                            | Rationale                                                                                              | Recommended Transformation / Notes                                                                                                                    |
# | -------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------ | ----------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Number of transactions by `device_id`**                                                          | Captures device activity; high counts may indicate frequent legitimate use or automated/stolen devices | Consider **log transformation** to reduce skew; optionally compute **variance relative to global distribution** to highlight unusually active devices |
# | **Number of transactions by `ip_address`**                                                         | Captures IP activity; shared IPs may indicate proxy usage or fraud rings                               | Same as above: log transformation and/or relative variance                                                                                            |
# | **Device-IP consistency (`device_ip_consistency`)**                                                | Binary indicator if a device is tied to exactly one IP                                                 | Keep as **binary 0/1**; no transformation needed                                                                                                      |
# | **Time between account setup and transaction (`time_between_setup_and_transaction`)**              | Fraudulent accounts often act immediately after signup                                                 | Keep numeric; consider **log transformation** if distribution is skewed                                                                               |
# | **Time since last transaction for same device/IP (`time_diff_device_id`, `time_diff_ip_address`)** | Captures repeated patterns; short intervals may indicate automation                                    | Keep numeric; impute missing for first transaction as e.g., median or max interval                                                                    |
# | **Standard deviation / variance of purchase value by device/IP (`purchase_val_std`)**              | Fraudulent transactions often have identical purchase amounts                                          | For devices/IPs with only one transaction, impute with **0** or **global median**; log-transform if highly skewed                                     |
# | **Month of transaction**                                                                           | Captures seasonality in fraud; January shows higher fraud                                              | Encode as **categorical** or transform into **fraud rate per month**                                                                                  |
# | **Customer demographics (`sex`, `age`)**                                                           | Gender and age may correlate with purchasing behavior                                                  | One-hot encode `sex`; standardize `age`                                                                                                               |
# | **Purchase value**                                                                                 | Core transaction feature; helps differentiate normal vs fraudulent spending patterns                   | Standardize or log-transform to reduce skew                                                                                                           |
# | **Country GDP (`gdp`)**                                                                            | Provides economic context; may correlate with fraud patterns                                           | Standardize; optionally combine with clustering of `sex`, `age`, `purchase_value` to create behavioral segments                                       |
#
# ---
#
# #### Additional Notes
#
# * **Skewed numeric features** (counts, purchase value, time differences) benefit from **log or standard scaling** for algorithms like logistic regression.
# * **Categorical variables** (`sex`, `month`) are one-hot encoded to allow the model to interpret discrete categories.
# * **Variance/std features** highlight unusual consistency in transactions, a common fraud signal.
# * **Time-based features** are treated as static numeric values for the baseline model; future work could implement **time-series or rolling-window features** for improved predictive power.
# * This feature set balances **interpretability** for stakeholders and **predictive power** for model performance.

# %%
# original distribution of age
sns.boxplot(y=fraud_df["age"], x=fraud_df["class"])
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
de

# %% [markdown]
# ### Do the same devices use the same browser/source when making transactions?

# %%
def plot_cat_by_device_distribution(df, col, binary=True):

    device_id_values = pd.merge(left=df[["device_id", "class"]], right=df.groupby("device_id")[col].nunique(), on="device_id")

    if binary:
        device_id_values[f"{col}_device_consistency"] = (device_id_values[col] == 1).astype(int)
        col = f"{col}_device_consistency"

    source_pct_table = (
        device_id_values.groupby([col, "class"])
        .size()
        .unstack(fill_value=0)
    )
    source_pct_table = source_pct_table.div(source_pct_table.sum(axis=1), axis=0)
    print(source_pct_table)
    # Plot stacked bar chart
    plt.figure(figsize=(8,5))

    plt.bar(source_pct_table.index, source_pct_table[0], label='Class 0')
    plt.bar(source_pct_table.index, source_pct_table[1], bottom=source_pct_table[0], label='Class 1')

    plt.xlabel("Number of distinct sources used by a device_id")
    plt.ylabel("Percentage")
    plt.title(f"Percentage of Class 0 and Class 1 by {col}")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_cat_by_device_distribution(fraud_df, "source")
# Out:
# class                             0         1
# source_device_consistency
# 0                          0.733342  0.266658
# 1                          0.915338  0.084662

# %%
plot_cat_by_device_distribution(fraud_df, "browser")
# Out:
# class                              0         1
# browser_device_consistency
# 0                           0.743712  0.256288
# 1                           0.915914  0.084086

# %% [markdown]
# ### Compare fraud vs legitimate `purchase_value` distributions

# %%
sns.kdeplot(data=fraud_df, x="purchase_value", hue="class")
# Out:
# <Axes: xlabel='purchase_value', ylabel='Density'>

# %% [markdown]
# #### By Month

# %%
fraud_df["purchase_time"] = pd.to_datetime(fraud_df["purchase_time"])
fraud_df["signup_time"] = pd.to_datetime(fraud_df["signup_time"])
fraud_df["month"] = fraud_df["purchase_time"].dt.month

monthly_stats = fraud_df.groupby(['month', 'class'])['purchase_value'].mean().unstack()

# %%
monthly_stats.plot(kind="bar")
plt.title("Average Purchase by Month")
plt.legend(["Legitimate", "Fraud"])

# %%
sns.boxplot(data=fraud_df, x="class", y="purchase_value")
# Out:
# <Axes: xlabel='class', ylabel='purchase_value'>

# %%
# Calculate monthly baselines
monthly_baselines = fraud_df.groupby('month').agg({
    'purchase_value': ['mean', 'median', 'std'],
    'class': 'mean'  # fraud rate
})

# Create deviation features
fraud_df['purchase_value_deviation_by_month'] = (
    fraud_df['purchase_value'] -
    fraud_df['month'].map(monthly_baselines['purchase_value']['mean'])
) / fraud_df['month'].map(monthly_baselines['purchase_value']['std'])

fraud_df['purchase_value_ratio_to_monthly_median'] = (
    fraud_df['purchase_value'] /
    fraud_df['month'].map(monthly_baselines['purchase_value']['median'])
)

fraud_df['month_fraud_rate'] = fraud_df['month'].map(monthly_baselines['class']['mean'])

# %%
sns.kdeplot(data=fraud_df, x="purchase_value_deviation_by_month", hue="class")
# Out:
# <Axes: xlabel='purchase_value_deviation_by_month', ylabel='Density'>

# %%
def purchase_by_cont(df, col="age"):
    df = df.copy()
    if col == "age":
        df['age_group'] = pd.cut(
                fraud_df['age'],
                bins=[0, 18, 25, 35, 50, 65, 100],
                labels=['under_18', '18_25', '26_35', '36_50', '51_65', 'over_65']
            )
        col = "age_group"

    group_stats = df.groupby(col)["purchase_value"].agg(["mean", "median"])
    print(group_stats)
    df = pd.merge(
        left=df,
        right=group_stats,
        on=col,
        how="left"
    )
    print(df.columns)

    df["dev_from_mean"] = df["purchase_value"] - df[f"mean"]
    df["dev_from_median"] = df["purchase_value"] - df[f"median"]
    
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    sns.kdeplot(data=df, x='dev_from_mean', hue='class', common_norm=False, ax=axes[0])
    plt.title(f"Deviation from {col} Mean by Fraud Class")
    
    sns.kdeplot(data=df, x='dev_from_median', hue='class', common_norm=False, ax=axes[1])
    plt.title(f"Deviation from {col} Median by Fraud Class")
    
    plt.show()

# %%
purchase_by_cont(fraud_df)
# Out:
# /var/folders/l3/pxhbl0b94cdd7tr_xs9sbypc0000gn/T/ipykernel_2106/2672275784.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_stats = df.groupby(col)["purchase_value"].agg(["mean", "median"])
#                 mean  median
# age_group
# under_18   36.625996    34.0
# 18_25      37.054593    35.0
# 26_35      36.818201    34.0
# 36_50      37.021156    35.0
# 51_65      36.985532    35.0
# over_65    39.153846    39.0
# Index(['user_id', 'signup_time', 'purchase_time', 'purchase_value',
#        'device_id', 'source', 'browser', 'sex', 'age', 'ip_address', 'class',
#        'age_group', 'mean', 'median'],
#       dtype='object')

# %%
_, p_left = mannwhitneyu(
    x=fraud_df[fraud_df["class"]==1]["purchase_value"],
    y=fraud_df[fraud_df["class"]==0]["purchase_value"],
    alternative="less"
)

_, p_val = mannwhitneyu(
    x=fraud_df[fraud_df["class"]==1]["purchase_value"],
    y=fraud_df[fraud_df["class"]==0]["purchase_value"],
    alternative="two-sided"
)

_, p_right = mannwhitneyu(
    x=fraud_df[fraud_df["class"]==1]["purchase_value"],
    y=fraud_df[fraud_df["class"]==0]["purchase_value"],
    alternative="greater"
)

print(f"Left-Tail: {p_left}, Two-Tail: {p_val}, Right-Tail: {p_right}")
# Out:
# Left-Tail: 0.6409928883741778, Two-Tail: 0.7180143745848777, Right-Tail: 0.35900718729243886

# %% [markdown]
# There is no significant differece in `purchase_value` in fraudulent and non-fraudulent transactions

# %% [markdown]
# ### Cross-border patterns
# - country_fraud_rate
# - is_high_risk_country

# %% [markdown]
# ## More Device/IP Behavioural Patterns
# - device lifespan
# - transactions in the last hour by device

# %%
 # Device longevity
device_stats = fraud_df.groupby('device_id').agg({
    'purchase_time': ['min', 'max', 'count'],
    'class': 'max'  # If any fraud
})
device_stats['lifespan_days'] = (
    device_stats['purchase_time']['max'] -
device_stats['purchase_time']['min']
).dt.total_seconds() / 86400

print("\nDevice Lifespan by Fraud Status:")
device_stats
# Out:
# Device Lifespan by Fraud Status:
#                     purchase_time                           class  \
#                               min                 max count   max
# device_id
# AAALBGNHHVMKG 2015-06-13 23:42:18 2015-06-13 23:42:18     1     0
# AAAWIHVCQELTP 2015-03-29 00:39:07 2015-03-29 00:39:07     1     0
# AAAXJHWCLISKY 2015-07-22 03:18:01 2015-07-22 03:18:01     1     0
# AAAXXOZJRZRAO 2015-01-01 04:25:23 2015-01-28 10:39:35    11     1
# AABFGRPBQHWFQ 2015-11-12 10:36:47 2015-11-12 10:36:47     1     0
# ...                           ...                 ...   ...   ...
# ZZZGSIJRNCXBJ 2015-04-12 04:54:26 2015-04-12 04:54:26     1     0
# ZZZIKLJSVSQMF 2015-10-24 17:29:39 2015-10-24 17:29:39     1     0
# ZZZKJIZHJEDFN 2015-09-07 03:15:41 2015-09-07 03:15:41     1     0
# ZZZMVOGBAJVTM 2015-08-06 10:45:33 2015-08-06 10:45:33     1     0
# ZZZXASJUVUNMV 2015-05-23 19:19:02 2015-05-23 19:19:02     1     0
#
#               lifespan_days
#
# device_id
# AAALBGNHHVMKG      0.000000
# AAAWIHVCQELTP      0.000000
# AAAXJHWCLISKY      0.000000
# AAAXXOZJRZRAO     27.259861
# AABFGRPBQHWFQ      0.000000
# ...                     ...
# ZZZGSIJRNCXBJ      0.000000
# ZZZIKLJSVSQMF      0.000000
# ZZZKJIZHJEDFN      0.000000
# ZZZMVOGBAJVTM      0.000000
# ZZZXASJUVUNMV      0.000000
#
# [137956 rows x 5 columns]
